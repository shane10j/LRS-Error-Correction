# %% [markdown]
# # Real ONT Benchmark Driver
#
# This notebook is a benchmark-grade experiment driver for OMEGA on GIAB-style ONT data.
#
# It now supports:
# - phased VCF and haplotagged BAM plumbing through preprocessing
# - region BED annotations for homopolymers, repeats, segmental duplications, low-complexity sequence, and variant-rich regions
# - HG002 primary training plus HG003/HG004 transfer evaluation planning
# - executable hooks for internal baselines, external baselines, corrected-read export, assembly, and variant-calling evaluation
# - environment-variable or workspace-relative path resolution instead of hardcoded local paths
# - device fallback (`cuda -> mps -> cpu`) when configs are generated
# - fail-fast validation before execution when required files are missing
#
# Recommended environment variables for the trio preset:
# - `HG002_READS_BAM`, `HG002_HAPLOTAGGED_BAM`, `HG002_PHASED_VCF`
# - `HG003_READS_BAM`, `HG003_HAPLOTAGGED_BAM`, `HG003_TRUTH_VCF`, `HG003_CONFIDENT_BED`, `HG003_PHASED_VCF`
# - `HG004_READS_BAM`, `HG004_HAPLOTAGGED_BAM`, `HG004_TRUTH_VCF`, `HG004_CONFIDENT_BED`, `HG004_PHASED_VCF`
# - `GIAB_HOMOPOLYMER_BED`, `GIAB_LOW_COMPLEXITY_BED`, `GIAB_SEGDUP_BED`, `GIAB_REPEAT_BED`, `GIAB_VARIANT_RICH_BED`
# - `OMEGA_HERRO_CMD_TEMPLATE`, `OMEGA_DECHAT_CMD_TEMPLATE`
# - `OMEGA_ASSEMBLER_CMD_TEMPLATE`, `OMEGA_VARIANT_CALL_CMD_TEMPLATE`, `OMEGA_HAPPY_CMD_TEMPLATE`
#
# The notebook defaults to an immediately runnable local training preset. Use `OMEGA_EXPERIMENT_PRESET=giab_trio_benchmark` once the full GIAB trio inputs are available.

# %%
from __future__ import annotations

import copy
import gzip
import hashlib
import importlib
import inspect
import json
import os
import subprocess
import sys
from pathlib import Path
from urllib.request import urlretrieve

import pandas as pd
import torch
import yaml
from IPython.display import display

def find_repo_root(start: Path) -> Path:
    for candidate in [start, *start.parents]:
        if (candidate / 'src').exists() and (candidate / 'scripts').exists() and (candidate / 'notebooks').exists():
            return candidate
    return start

ROOT = find_repo_root(Path.cwd().resolve())
sys.path.insert(0, str(ROOT / 'src'))

EXPERIMENT_PRESET = os.environ.get('OMEGA_EXPERIMENT_PRESET', 'hg002_chr20_small_benchmark')
SELECTED_RUNS = [token.strip() for token in os.environ.get('OMEGA_SELECTED_RUNS', 'full').split(',') if token.strip()]
PREFERRED_DEVICE = os.environ.get('OMEGA_DEVICE', 'auto')
VALIDATE_ON_PLAN = os.environ.get('OMEGA_VALIDATE_ON_PLAN', '0') == '1'

RUN_PREPROCESS = os.environ.get('OMEGA_RUN_PREPROCESS', '0') == '1'
RUN_TRAIN = os.environ.get('OMEGA_RUN_TRAIN', '1') == '1'
RUN_TEST = os.environ.get('OMEGA_RUN_TEST', '1') == '1'
RUN_BASELINES = os.environ.get('OMEGA_RUN_BASELINES', '0') == '1'
RUN_EXTERNAL_BASELINES = os.environ.get('OMEGA_RUN_EXTERNAL_BASELINES', '0') == '1'
RUN_DOWNSTREAM = os.environ.get('OMEGA_RUN_DOWNSTREAM', '0') == '1'

PROFILE_PRESETS = {
    'giab_hg002_local': {
        'mode': 'prealigned_benchmark',
        'run_name': 'giab_hg002_local',
        'datasets': [
            {
                'name': 'hg002_local',
                'role': 'primary',
                'reference_fasta': {'default': 'data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna', 'required': True},
                'reads_bam': {'env': 'HG002_READS_BAM', 'default': 'data/raw/giab/hg002/HG002_GRCh38_ONT-UL_UCSC_20200508.phased.bam', 'required': True},
                'truth_vcf': {'default': 'data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark.vcf.gz', 'required': True},
                'confident_bed': {'default': 'data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark_noinconsistent.bed', 'required': True},
                'phased_vcf': {'env': 'HG002_PHASED_VCF', 'default': '', 'required': False},
                'haplotagged_bam': {'env': 'HG002_HAPLOTAGGED_BAM', 'default': '', 'required': False},
                'train_contigs': 'chr1,chr2,chr3,chr4,chr5,chr6,chr7,chr8,chr9,chr10,chr11,chr12,chr13,chr14,chr15,chr16',
                'val_contigs': 'chr17,chr18,chr19',
                'test_contigs': 'chr20,chr21,chr22,chrX',
            },
        ],
        'region_beds': {
            'homopolymer': {'env': 'GIAB_HOMOPOLYMER_BED', 'default': '', 'required': False},
            'low_complexity': {'env': 'GIAB_LOW_COMPLEXITY_BED', 'default': '', 'required': False},
            'segmental_duplication': {'env': 'GIAB_SEGDUP_BED', 'default': '', 'required': False},
            'repeat': {'env': 'GIAB_REPEAT_BED', 'default': '', 'required': False},
            'variant_rich': {'env': 'GIAB_VARIANT_RICH_BED', 'default': '', 'required': False},
        },
        'checkpoint_weights': {'overcorrection': 3.0, 'hard_edit_fp': 2.0, 'length_ratio': 0.25},
        'stages': [
            {'name': 'stage1_1kb', 'window_size': 1024, 'window_overlap': 256, 'min_window_size': 512, 'max_target_len': 1024, 'max_support_len': 1024, 'batch_size': 4, 'epochs': 8, 'min_read_length': 10000, 'max_supports': 16, 'min_supports_per_window': 4, 'min_mapq': 20},
            {'name': 'stage2_4kb', 'window_size': 4096, 'window_overlap': 1024, 'min_window_size': 1024, 'max_target_len': 4096, 'max_support_len': 4096, 'batch_size': 2, 'epochs': 8, 'min_read_length': 10000, 'max_supports': 24, 'min_supports_per_window': 6, 'min_mapq': 20},
            {'name': 'stage3_8kb', 'window_size': 8192, 'window_overlap': 2048, 'min_window_size': 2048, 'max_target_len': 8192, 'max_support_len': 8192, 'batch_size': 1, 'epochs': 6, 'min_read_length': 10000, 'max_supports': 32, 'min_supports_per_window': 8, 'min_mapq': 20},
        ],
    },
    'local_ready_training': {
        'mode': 'preprocessed_dataset',
        'run_name': 'local_ready_training',
        'datasets': [
            {
                'name': 'uti89_local',
                'role': 'primary',
                'manifest_path': {'default': 'data/real_uti89_notebook/manifest.json', 'required': True},
                'train_path': {'default': 'data/real_uti89_notebook/train.jsonl', 'required': True},
                'val_path': {'default': 'data/real_uti89_notebook/val.jsonl', 'required': True},
                'test_path': {'default': 'data/real_uti89_notebook/test.jsonl', 'required': True},
                'reference_fasta': {'default': 'data/raw/uti89/reference.fna', 'required': False},
                'reads_bam': {'default': 'data/real_uti89_notebook/aligned.sorted.bam', 'required': False},
                'truth_vcf': {'default': '', 'required': False},
                'confident_bed': {'default': '', 'required': False},
                'phased_vcf': {'default': '', 'required': False},
                'haplotagged_bam': {'default': 'data/real_uti89_notebook/aligned.sorted.bam', 'required': False},
                'train_contigs': '',
                'val_contigs': '',
                'test_contigs': '',
            },
        ],
        'region_beds': {},
        'checkpoint_weights': {'overcorrection': 3.0, 'hard_edit_fp': 2.0, 'length_ratio': 0.25},
        'stages': [
            {'name': 'stage1_local', 'window_size': 1024, 'window_overlap': 256, 'min_window_size': 512, 'max_target_len': 1024, 'max_support_len': 1024, 'batch_size': 4, 'epochs': 10, 'min_read_length': 0, 'max_supports': 16, 'min_supports_per_window': 0, 'min_mapq': 0},
        ],
    },
    'giab_trio_benchmark': {
        'mode': 'prealigned_benchmark',
        'run_name': 'giab_trio_benchmark',
        'datasets': [
            {
                'name': 'hg002_primary',
                'role': 'primary',
                'reference_fasta': {'env': 'GIAB_REFERENCE_FASTA', 'default': 'data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna', 'required': True},
                'reads_bam': {'env': 'HG002_READS_BAM', 'default': '', 'required': True},
                'truth_vcf': {'env': 'HG002_TRUTH_VCF', 'default': 'data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark.vcf.gz', 'required': True},
                'confident_bed': {'env': 'HG002_CONFIDENT_BED', 'default': 'data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark_noinconsistent.bed', 'required': True},
                'phased_vcf': {'env': 'HG002_PHASED_VCF', 'default': '', 'required': False},
                'haplotagged_bam': {'env': 'HG002_HAPLOTAGGED_BAM', 'default': '', 'required': False},
                'train_contigs': 'chr1,chr2,chr3,chr4,chr5,chr6,chr7,chr8,chr9,chr10,chr11,chr12,chr13,chr14,chr15,chr16',
                'val_contigs': 'chr17,chr18,chr19',
                'test_contigs': 'chr20,chr21,chr22,chrX',
            },
            {
                'name': 'hg003_transfer',
                'role': 'eval_only',
                'reference_fasta': {'env': 'GIAB_REFERENCE_FASTA', 'default': 'data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna', 'required': True},
                'reads_bam': {'env': 'HG003_READS_BAM', 'default': '', 'required': True},
                'truth_vcf': {'env': 'HG003_TRUTH_VCF', 'default': '', 'required': True},
                'confident_bed': {'env': 'HG003_CONFIDENT_BED', 'default': '', 'required': True},
                'phased_vcf': {'env': 'HG003_PHASED_VCF', 'default': '', 'required': False},
                'haplotagged_bam': {'env': 'HG003_HAPLOTAGGED_BAM', 'default': '', 'required': False},
                'train_contigs': '',
                'val_contigs': '',
                'test_contigs': 'chr20,chr21,chr22,chrX',
            },
            {
                'name': 'hg004_transfer',
                'role': 'eval_only',
                'reference_fasta': {'env': 'GIAB_REFERENCE_FASTA', 'default': 'data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna', 'required': True},
                'reads_bam': {'env': 'HG004_READS_BAM', 'default': '', 'required': True},
                'truth_vcf': {'env': 'HG004_TRUTH_VCF', 'default': '', 'required': True},
                'confident_bed': {'env': 'HG004_CONFIDENT_BED', 'default': '', 'required': True},
                'phased_vcf': {'env': 'HG004_PHASED_VCF', 'default': '', 'required': False},
                'haplotagged_bam': {'env': 'HG004_HAPLOTAGGED_BAM', 'default': '', 'required': False},
                'train_contigs': '',
                'val_contigs': '',
                'test_contigs': 'chr20,chr21,chr22,chrX',
            },
        ],
        'region_beds': {
            'homopolymer': {'env': 'GIAB_HOMOPOLYMER_BED', 'default': '', 'required': False},
            'low_complexity': {'env': 'GIAB_LOW_COMPLEXITY_BED', 'default': '', 'required': False},
            'segmental_duplication': {'env': 'GIAB_SEGDUP_BED', 'default': '', 'required': False},
            'repeat': {'env': 'GIAB_REPEAT_BED', 'default': '', 'required': False},
            'variant_rich': {'env': 'GIAB_VARIANT_RICH_BED', 'default': '', 'required': False},
        },
        'checkpoint_weights': {'overcorrection': 3.0, 'hard_edit_fp': 2.0, 'length_ratio': 0.25},
        'stages': [
            {'name': 'stage1_1kb', 'window_size': 1024, 'window_overlap': 256, 'min_window_size': 512, 'max_target_len': 1024, 'max_support_len': 1024, 'batch_size': 4, 'epochs': 8, 'min_read_length': 10000, 'max_supports': 16, 'min_supports_per_window': 4, 'min_mapq': 20},
            {'name': 'stage2_4kb', 'window_size': 4096, 'window_overlap': 1024, 'min_window_size': 1024, 'max_target_len': 4096, 'max_support_len': 4096, 'batch_size': 2, 'epochs': 8, 'min_read_length': 10000, 'max_supports': 24, 'min_supports_per_window': 6, 'min_mapq': 20},
            {'name': 'stage3_8kb', 'window_size': 8192, 'window_overlap': 2048, 'min_window_size': 2048, 'max_target_len': 8192, 'max_support_len': 8192, 'batch_size': 1, 'epochs': 6, 'min_read_length': 10000, 'max_supports': 32, 'min_supports_per_window': 8, 'min_mapq': 20},
        ],
    },
}
from omega_longread.benchmark_presets import NOTEBOOK_PRESETS
PROFILE_PRESETS.update(copy.deepcopy(NOTEBOOK_PRESETS))

ALL_RUNS = [
    {'name': 'full', 'support_mode': 'full', 'description': 'Target + overlap-conditioned support encoder'},
    {'name': 'target_only', 'support_mode': 'target_only', 'description': 'Target encoder only; support path disabled'},
    {'name': 'masked_target', 'support_mode': 'masked_target', 'description': 'Support-conditioned with masked target features'},
]

# %%
def resolve_spec(spec, base_dir: Path) -> tuple[str, str | None, bool]:
    if isinstance(spec, str):
        raw = spec.strip()
        env_var = None
        required = bool(raw)
    else:
        env_var = spec.get('env')
        raw = os.environ.get(env_var, '').strip() if env_var else ''
        if not raw:
            raw = str(spec.get('default', '')).strip()
        required = bool(spec.get('required', False))
    if not raw:
        return '', env_var, required
    raw = os.path.expanduser(os.path.expandvars(raw))
    path = Path(raw)
    if not path.is_absolute():
        path = base_dir / path
    return str(path.resolve()), env_var, required


def resolve_dataset_entry(entry: dict, base_dir: Path) -> dict:
    resolved = dict(entry)
    required_fields = {}
    for field in ['manifest_path', 'train_path', 'val_path', 'test_path', 'reference_fasta', 'reads_bam', 'truth_vcf', 'confident_bed', 'phased_vcf', 'haplotagged_bam']:
        value, env_var, required = resolve_spec(entry.get(field, ''), base_dir)
        resolved[field] = value
        required_fields[field] = {'env_var': env_var, 'required': required}
    if not resolved['haplotagged_bam']:
        resolved['haplotagged_bam'] = resolved['reads_bam']
    resolved['_requirements'] = required_fields
    return resolved


def resolve_profile(profile: dict, base_dir: Path) -> dict:
    resolved = copy.deepcopy(profile)
    resolved['datasets'] = [resolve_dataset_entry(dataset, base_dir) for dataset in profile['datasets']]
    region_beds = {}
    region_requirements = {}
    for name, spec in profile.get('region_beds', {}).items():
        path, env_var, required = resolve_spec(spec, base_dir)
        region_beds[name] = path
        region_requirements[name] = {'env_var': env_var, 'required': required}
    resolved['region_beds'] = region_beds
    resolved['_region_requirements'] = region_requirements
    return resolved


def validate_profile_inputs(profile: dict) -> list[dict]:
    rows = []
    for dataset in profile['datasets']:
        for field in ['manifest_path', 'train_path', 'val_path', 'test_path', 'reference_fasta', 'reads_bam', 'truth_vcf', 'confident_bed', 'phased_vcf', 'haplotagged_bam']:
            value = dataset.get(field, '')
            requirement = dataset.get('_requirements', {}).get(field, {})
            required = bool(requirement.get('required', False))
            env_var = requirement.get('env_var')
            rows.append({
                'dataset': dataset['name'],
                'field': field,
                'path': value,
                'exists': bool(value) and Path(value).exists(),
                'required': required,
                'env_var': env_var or '',
            })
    for name, path in profile.get('region_beds', {}).items():
        req = profile.get('_region_requirements', {}).get(name, {})
        rows.append({
            'dataset': '*regions*',
            'field': name,
            'path': path,
            'exists': bool(path) and Path(path).exists(),
            'required': bool(req.get('required', False)),
            'env_var': req.get('env_var') or '',
        })
    return rows


def missing_required_inputs(rows: list[dict]) -> list[dict]:
    return [row for row in rows if row['required'] and not row['exists']]


def pick_device(preferred: str) -> tuple[str, bool]:
    preferred = preferred.lower().strip()
    if preferred in {'', 'auto'}:
        preferred = 'cuda'
    if preferred == 'cuda':
        if torch.cuda.is_available():
            return 'cuda', True
        if getattr(torch.backends, 'mps', None) is not None and torch.backends.mps.is_available():
            return 'mps', False
        return 'cpu', False
    if preferred == 'mps':
        if getattr(torch.backends, 'mps', None) is not None and torch.backends.mps.is_available():
            return 'mps', False
        if torch.cuda.is_available():
            return 'cuda', True
        return 'cpu', False
    return 'cpu', False


def run_cmd(cmd, cwd=ROOT, env=None, dry_run=False):
    pretty = ' '.join(str(x) for x in cmd)
    print(pretty)
    if dry_run:
        return None
    return subprocess.run(cmd, cwd=cwd, env=env, check=True)


def stringify_cmd(cmd):
    return ' '.join(str(x) for x in cmd)


def safe_rel(path: Path) -> str:
    try:
        return str(path.relative_to(ROOT))
    except ValueError:
        return str(path)


def ensure_demo_inputs(profile):
    import pysam

    raw_dir = ROOT / 'data' / 'raw' / 'uti89'
    raw_dir.mkdir(parents=True, exist_ok=True)
    reference_gz = raw_dir / 'reference.fna.gz'
    reference_fa = raw_dir / 'reference.fna'
    fastq_urls = profile.get('fastq_urls', [])
    fastq_paths = [raw_dir / Path(url).name for url in fastq_urls]
    downloads = {reference_gz: profile['reference_gz_url']}
    downloads.update({path: url for path, url in zip(fastq_paths, fastq_urls)})
    for path, url in downloads.items():
        if path.exists() and path.stat().st_size > 0:
            continue
        urlretrieve(url, path)
    if not reference_fa.exists():
        with gzip.open(reference_gz, 'rb') as src, open(reference_fa, 'wb') as dst:
            dst.write(src.read())
    if not (reference_fa.with_suffix(reference_fa.suffix + '.fai')).exists():
        pysam.faidx(str(reference_fa))
    return {'reference_fasta': reference_fa, 'fastq_paths': fastq_paths}


def prepare_demo_stage(profile, stage_cfg, stage_dir):
    import mappy as mp
    import pysam
    import omega_longread.preprocessing as preprocessing

    preprocessing = importlib.reload(preprocessing)
    inputs = ensure_demo_inputs(profile)
    reference_fa = Path(inputs['reference_fasta'])
    fastq_paths = [Path(p) for p in inputs['fastq_paths']]
    unsorted_bam = stage_dir / 'aligned.unsorted.bam'
    sorted_bam = stage_dir / 'aligned.sorted.bam'
    train_jsonl = stage_dir / 'train.jsonl'
    val_jsonl = stage_dir / 'val.jsonl'
    test_jsonl = stage_dir / 'test.jsonl'

    def revcomp(seq: str) -> str:
        table = str.maketrans('ACGTNacgtn', 'TGCANtgcan')
        return seq.translate(table)[::-1]

    def iter_fastq(path: Path):
        with gzip.open(path, 'rt') as handle:
            while True:
                name = handle.readline().strip()
                if not name:
                    return
                seq = handle.readline().strip()
                handle.readline()
                qual = handle.readline().strip()
                yield name[1:], seq, qual

    def full_cigar(hit, query_len: int) -> str:
        if hit.strand < 0:
            left_soft = query_len - hit.q_en
            right_soft = hit.q_st
        else:
            left_soft = hit.q_st
            right_soft = query_len - hit.q_en
        parts = []
        if left_soft > 0:
            parts.append(f'{left_soft}S')
        parts.append(hit.cigar_str)
        if right_soft > 0:
            parts.append(f'{right_soft}S')
        return ''.join(parts)

    reads = []
    for fq in fastq_paths:
        for name, seq, qual in iter_fastq(fq):
            if len(seq) >= stage_cfg['min_read_length']:
                reads.append((name, seq, qual, fq.name))
    reads.sort(key=lambda row: len(row[1]), reverse=True)
    reads = reads[: stage_cfg.get('max_reads', len(reads))]

    aligner = mp.Aligner(str(reference_fa), preset='map-ont')
    fasta = pysam.FastaFile(str(reference_fa))
    header = {'HD': {'VN': '1.6', 'SO': 'unsorted'}, 'SQ': [{'SN': name, 'LN': length} for name, length in zip(fasta.references, fasta.lengths)]}
    ref_to_id = {name: idx for idx, name in enumerate(fasta.references)}

    with pysam.AlignmentFile(str(unsorted_bam), 'wb', header=header) as bam:
        for name, seq, qual, source in reads:
            hits = [hit for hit in aligner.map(seq) if hit.is_primary]
            if not hits:
                continue
            hit = max(hits, key=lambda h: (h.mapq, h.mlen, h.blen))
            aln = pysam.AlignedSegment()
            aln.query_name = f'{source}|{name}'
            aln.flag = 16 if hit.strand < 0 else 0
            aln.reference_id = ref_to_id[hit.ctg]
            aln.reference_start = hit.r_st
            aln.mapping_quality = int(hit.mapq)
            aln.cigarstring = full_cigar(hit, len(seq))
            if hit.strand < 0:
                aln.query_sequence = revcomp(seq)
                aln.query_qualities = pysam.qualitystring_to_array(qual[::-1])
            else:
                aln.query_sequence = seq
                aln.query_qualities = pysam.qualitystring_to_array(qual)
            bam.write(aln)
    pysam.sort('-o', str(sorted_bam), str(unsorted_bam))
    pysam.index(str(sorted_bam))

    build_read_encoding = preprocessing.build_read_encoding
    build_window_example = preprocessing.build_window_example
    iter_windows = preprocessing.iter_windows
    VariantLookup = preprocessing.VariantLookup
    counts = {'train': 0, 'val': 0, 'test': 0}
    files = {'train': open(train_jsonl, 'w', encoding='utf-8'), 'val': open(val_jsonl, 'w', encoding='utf-8'), 'test': open(test_jsonl, 'w', encoding='utf-8')}
    try:
        with pysam.AlignmentFile(str(sorted_bam), 'rb', reference_filename=str(reference_fa)) as bam:
            for aln in bam.fetch(until_eof=True):
                enc = build_read_encoding(aln, fasta, max_insertions_per_pos=2)
                if enc is None or len(enc.target_bases) < stage_cfg['min_window_size']:
                    continue
                digest = int(hashlib.md5(enc.read_id.encode()).hexdigest(), 16) % 10
                split = 'train' if digest < 8 else ('val' if digest == 8 else 'test')
                for ws, we in iter_windows(len(enc.target_bases), stage_cfg['window_size'], stage_cfg['window_overlap'], stage_cfg['min_window_size']):
                    ex = build_window_example(
                        target_aln=aln,
                        read_encoding=enc,
                        support_bam=bam,
                        variant_lookup=VariantLookup(None),
                        phased_variant_lookup=None,
                        confidence_lookup=None,
                        region_lookups={},
                        window_start=ws,
                        window_end=we,
                        max_supports=stage_cfg['max_supports'],
                        min_supports_per_window=stage_cfg['min_supports_per_window'],
                        min_mapq=stage_cfg['min_mapq'],
                        min_confident_fraction=0.0,
                        min_mapped_fraction=0.6,
                        support_disagreement_threshold=0.7,
                        min_support_depth=2,
                        max_insertions_per_pos=2,
                    )
                    if ex is None:
                        continue
                    files[split].write(json.dumps(ex) + '\n')
                    counts[split] += 1
    finally:
        for handle in files.values():
            handle.close()

    manifest = {'counts': counts, 'reference_fasta': str(reference_fa), 'reads_bam': str(sorted_bam), 'haplotagged_bam': str(sorted_bam), 'region_beds': {}, 'train_path': str(train_jsonl), 'val_path': str(val_jsonl), 'test_path': str(test_jsonl)}
    (stage_dir / 'manifest.json').write_text(json.dumps(manifest, indent=2))
    return manifest

# %%
def expand_small_benchmark_coverage_variants(profile):
    if EXPERIMENT_PRESET != 'hg002_chr20_small_benchmark':
        return profile
    expanded = copy.deepcopy(profile)
    base_primary = next((dataset for dataset in expanded['datasets'] if dataset['name'] == 'hg002_chr20_primary'), None)
    if base_primary is None:
        return expanded
    requested_coverages = os.environ.get('OMEGA_SMALL_BENCHMARK_COVERAGES', '').strip()
    if requested_coverages:
        selected_coverages = [int(token.strip()) for token in requested_coverages.split(',') if token.strip()]
    else:
        selected_coverages = list(expanded.get('default_coverage_targets', expanded.get('coverage_targets', [])))
    coverage_datasets = []
    for coverage in selected_coverages:
        cov_value = int(coverage)
        cov_tag = f'{cov_value}x'
        reads_env = f'HG002_CHR20_{cov_value}X_READS_BAM'
        hap_env = f'HG002_CHR20_{cov_value}X_HAPLOTAGGED_BAM'
        reads_bam = os.environ.get(reads_env, '').strip()
        if not reads_bam:
            default_candidate = ROOT / 'data' / 'subsets' / f'hg002_chr20_{cov_tag}' / 'HG002.giab.subset.bam'
            if default_candidate.exists():
                reads_bam = str(default_candidate.resolve())
            else:
                reads_bam = base_primary.get('reads_bam', '')
        haplotagged_bam = os.environ.get(hap_env, '').strip() or reads_bam
        dataset = copy.deepcopy(base_primary)
        dataset['name'] = f"{base_primary['name']}_{cov_tag}"
        dataset['coverage_tag'] = cov_tag
        dataset['role'] = 'primary' if not coverage_datasets else 'train_variant'
        dataset['reads_bam'] = str(Path(reads_bam).resolve()) if reads_bam else ''
        dataset['haplotagged_bam'] = str(Path(haplotagged_bam).resolve()) if haplotagged_bam else dataset['reads_bam']
        reqs = copy.deepcopy(dataset.get('_requirements', {}))
        if 'reads_bam' in reqs:
            reqs['reads_bam']['env_var'] = reads_env
            reqs['reads_bam']['required'] = True
        if 'haplotagged_bam' in reqs:
            reqs['haplotagged_bam']['env_var'] = hap_env
        dataset['_requirements'] = reqs
        coverage_datasets.append(dataset)
    expanded['datasets'] = coverage_datasets + [dataset for dataset in expanded['datasets'] if dataset['role'] != 'primary']
    return expanded

profile = expand_small_benchmark_coverage_variants(resolve_profile(PROFILE_PRESETS[EXPERIMENT_PRESET], ROOT))
selected_run_set = set(SELECTED_RUNS)
unknown_runs = sorted(selected_run_set - {run['name'] for run in ALL_RUNS})
if unknown_runs:
    raise ValueError(f'Unknown run names requested: {unknown_runs}')
SELECTED_MODEL_RUNS = [run for run in ALL_RUNS if run['name'] in selected_run_set]
if not SELECTED_MODEL_RUNS:
    raise ValueError('SELECTED_RUNS must contain at least one run name.')
def dataset_ready_for_mode(dataset_cfg, mode):
    if mode == 'preprocessed_dataset':
        return all(dataset_cfg.get(field) and Path(dataset_cfg[field]).exists() for field in ['train_path', 'val_path', 'test_path'])
    return bool(dataset_cfg.get('reads_bam')) and Path(dataset_cfg['reads_bam']).exists() and bool(dataset_cfg.get('reference_fasta')) and Path(dataset_cfg['reference_fasta']).exists()

PRIMARY_ANALYSIS_RUN = SELECTED_MODEL_RUNS[0]['name']
TRAIN_DATASETS = [dataset for dataset in profile['datasets'] if dataset['role'] in {'primary', 'train_variant'}]
PRIMARY_DATASET = TRAIN_DATASETS[0]
EVAL_DATASETS = [dataset for dataset in profile['datasets'] if dataset['role'] in {'primary', 'train_variant', 'eval_only'}]
ACTIVE_TRAIN_DATASETS = [dataset for dataset in TRAIN_DATASETS if dataset_ready_for_mode(dataset, profile['mode'])]
ACTIVE_EVAL_DATASETS = [dataset for dataset in EVAL_DATASETS if dataset_ready_for_mode(dataset, profile['mode'])]
SKIPPED_OPTIONAL_DATASETS = [dataset['name'] for dataset in EVAL_DATASETS if dataset not in ACTIVE_EVAL_DATASETS and dataset['role'] == 'eval_only']
RESOLVED_DEVICE, RESOLVED_MIXED_PRECISION = pick_device(PREFERRED_DEVICE)

RUN_ROOT = ROOT / 'data' / profile['run_name']
CKPT_ROOT = ROOT / 'checkpoints' / profile['run_name']
OUT_ROOT = ROOT / 'outputs' / profile['run_name']
CONFIG_ROOT = ROOT / 'configs' / profile['run_name']
PLAN_PATH = OUT_ROOT / 'benchmark_plan.json'
for path in [RUN_ROOT, CKPT_ROOT, OUT_ROOT, CONFIG_ROOT]:
    path.mkdir(parents=True, exist_ok=True)

validation_rows = validate_profile_inputs(profile)
validation_df = pd.DataFrame(validation_rows)
missing_inputs_df = pd.DataFrame(missing_required_inputs(validation_rows))
print('python:', sys.executable)
print('preset:', EXPERIMENT_PRESET)
print('selected runs:', SELECTED_RUNS)
print('device:', RESOLVED_DEVICE, 'mixed_precision:', RESOLVED_MIXED_PRECISION)
print('training datasets:', [dataset['name'] for dataset in TRAIN_DATASETS])
print('active training datasets:', [dataset['name'] for dataset in ACTIVE_TRAIN_DATASETS])
print('active eval datasets:', [dataset['name'] for dataset in ACTIVE_EVAL_DATASETS])
if SKIPPED_OPTIONAL_DATASETS:
    print('skipping optional eval datasets with missing inputs:', SKIPPED_OPTIONAL_DATASETS)
display(validation_df)
display(pd.DataFrame(profile['stages']))
if VALIDATE_ON_PLAN and not missing_inputs_df.empty:
    raise FileNotFoundError('Missing required benchmark inputs:\n' + missing_inputs_df.to_string(index=False))
# Out:
# python: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python
# preset: hg002_chr20_small_benchmark
# selected runs: ['full']
# device: mps mixed_precision: False
# training datasets: ['hg002_chr20_primary_8x', 'hg002_chr20_primary_12x', 'hg002_chr20_primary_20x']
# active training datasets: ['hg002_chr20_primary_8x', 'hg002_chr20_primary_12x', 'hg002_chr20_primary_20x']
# active eval datasets: ['hg002_chr20_primary_8x', 'hg002_chr20_primary_12x', 'hg002_chr20_primary_20x']
# skipping optional eval datasets with missing inputs: ['hg003_chr20_transfer', 'hg004_chr20_transfer']
#                     dataset                  field  \
# 0    hg002_chr20_primary_8x          manifest_path
# 1    hg002_chr20_primary_8x             train_path
# 2    hg002_chr20_primary_8x               val_path
# 3    hg002_chr20_primary_8x              test_path
# 4    hg002_chr20_primary_8x        reference_fasta
# 5    hg002_chr20_primary_8x              reads_bam
# 6    hg002_chr20_primary_8x              truth_vcf
# 7    hg002_chr20_primary_8x          confident_bed
# 8    hg002_chr20_primary_8x             phased_vcf
# 9    hg002_chr20_primary_8x        haplotagged_bam
# 10  hg002_chr20_primary_12x          manifest_path
# 11  hg002_chr20_primary_12x             train_path
# 12  hg002_chr20_primary_12x               val_path
# 13  hg002_chr20_primary_12x              test_path
# 14  hg002_chr20_primary_12x        reference_fasta
# 15  hg002_chr20_primary_12x              reads_bam
# 16  hg002_chr20_primary_12x              truth_vcf
# 17  hg002_chr20_primary_12x          confident_bed
# 18  hg002_chr20_primary_12x             phased_vcf
# 19  hg002_chr20_primary_12x        haplotagged_bam
# 20  hg002_chr20_primary_20x          manifest_path
# 21  hg002_chr20_primary_20x             train_path
# 22  hg002_chr20_primary_20x               val_path
# 23  hg002_chr20_primary_20x              test_path
# 24  hg002_chr20_primary_20x        reference_fasta
# 25  hg002_chr20_primary_20x              reads_bam
# 26  hg002_chr20_primary_20x              truth_vcf
# 27  hg002_chr20_primary_20x          confident_bed
# 28  hg002_chr20_primary_20x             phased_vcf
# 29  hg002_chr20_primary_20x        haplotagged_bam
# 30     hg003_chr20_transfer          manifest_path
# 31     hg003_chr20_transfer             train_path
# 32     hg003_chr20_transfer               val_path
# 33     hg003_chr20_transfer              test_path
# 34     hg003_chr20_transfer        reference_fasta
# 35     hg003_chr20_transfer              reads_bam
# 36     hg003_chr20_transfer              truth_vcf
# 37     hg003_chr20_transfer          confident_bed
# 38     hg003_chr20_transfer             phased_vcf
# 39     hg003_chr20_transfer        haplotagged_bam
# 40     hg004_chr20_transfer          manifest_path
# 41     hg004_chr20_transfer             train_path
# 42     hg004_chr20_transfer               val_path
# 43     hg004_chr20_transfer              test_path
# 44     hg004_chr20_transfer        reference_fasta
# 45     hg004_chr20_transfer              reads_bam
# 46     hg004_chr20_transfer              truth_vcf
# 47     hg004_chr20_transfer          confident_bed
# 48     hg004_chr20_transfer             phased_vcf
# 49     hg004_chr20_transfer        haplotagged_bam
# 50                *regions*            homopolymer
# 51                *regions*          tandem_repeat
# 52                *regions*         low_complexity
# 53                *regions*  segmental_duplication
# 54                *regions*                 repeat
# 55                *regions*           variant_rich
#
#                                                  path  exists  required  \
# 0                                                       False     False
# 1                                                       False     False
# 2                                                       False     False
# 3                                                       False     False
# 4   /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 5   /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 6   /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 7   /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 8                                                       False     False
# 9   /Users/shanejayasundera/LRS-Error-Correction/d...    True     False
# 10                                                      False     False
# 11                                                      False     False
# 12                                                      False     False
# 13                                                      False     False
# 14  /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 15  /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 16  /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 17  /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 18                                                      False     False
# 19  /Users/shanejayasundera/LRS-Error-Correction/d...    True     False
# 20                                                      False     False
# 21                                                      False     False
# 22                                                      False     False
# 23                                                      False     False
# 24  /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 25  /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 26  /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 27  /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 28                                                      False     False
# 29  /Users/shanejayasundera/LRS-Error-Correction/d...    True     False
# 30                                                      False     False
# 31                                                      False     False
# 32                                                      False     False
# 33                                                      False     False
# 34  /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 35                                                      False     False
# 36                                                      False     False
# 37                                                      False     False
# 38                                                      False     False
# 39                                                      False     False
# 40                                                      False     False
# 41                                                      False     False
# 42                                                      False     False
# 43                                                      False     False
# 44  /Users/shanejayasundera/LRS-Error-Correction/d...    True      True
# 45                                                      False     False
# 46                                                      False     False
# 47                                                      False     False
# 48                                                      False     False
# 49                                                      False     False
# 50                                                      False     False
# 51                                                      False     False
# 52                                                      False     False
# 53                                                      False     False
# 54                                                      False     False
# 55                                                      False     False
#
#                             env_var
# 0
# 1
# 2
# 3
# 4              GIAB_REFERENCE_FASTA
# 5          HG002_CHR20_8X_READS_BAM
# 6                   HG002_TRUTH_VCF
# 7               HG002_CONFIDENT_BED
# 8                  HG002_PHASED_VCF
# 9    HG002_CHR20_8X_HAPLOTAGGED_BAM
# 10
# 11
# 12
# 13
# 14             GIAB_REFERENCE_FASTA
# 15        HG002_CHR20_12X_READS_BAM
# 16                  HG002_TRUTH_VCF
# 17              HG002_CONFIDENT_BED
# 18                 HG002_PHASED_VCF
# 19  HG002_CHR20_12X_HAPLOTAGGED_BAM
# 20
# 21
# 22
# 23
# 24             GIAB_REFERENCE_FASTA
# 25        HG002_CHR20_20X_READS_BAM
# 26                  HG002_TRUTH_VCF
# 27              HG002_CONFIDENT_BED
# 28                 HG002_PHASED_VCF
# 29  HG002_CHR20_20X_HAPLOTAGGED_BAM
# 30
# 31
# 32
# 33
# 34             GIAB_REFERENCE_FASTA
# 35            HG003_CHR20_READS_BAM
# 36                  HG003_TRUTH_VCF
# 37              HG003_CONFIDENT_BED
# 38                 HG003_PHASED_VCF
# 39      HG003_CHR20_HAPLOTAGGED_BAM
# 40
# 41
# 42
# 43
# 44             GIAB_REFERENCE_FASTA
# 45            HG004_CHR20_READS_BAM
# 46                  HG004_TRUTH_VCF
# 47              HG004_CONFIDENT_BED
# 48                 HG004_PHASED_VCF
# 49      HG004_CHR20_HAPLOTAGGED_BAM
# 50             GIAB_HOMOPOLYMER_BED
# 51           GIAB_TANDEM_REPEAT_BED
# 52          GIAB_LOW_COMPLEXITY_BED
# 53                  GIAB_SEGDUP_BED
# 54                  GIAB_REPEAT_BED
# 55            GIAB_VARIANT_RICH_BED
#           name  window_size  window_overlap  min_window_size  max_target_len  \
# 0  chr20_small         2048             512             1024            2048
#
#    max_support_len  batch_size  epochs  min_read_length  max_supports  \
# 0             2048           2       7            10000            24
#
#    min_supports_per_window  min_mapq  max_examples_per_split  \
# 0                        4        20                    1500
#
#    early_stopping_patience
# 0                        2

# %%
def build_preprocess_command(dataset_cfg, stage_cfg, output_dir):
    cmd = [
        sys.executable,
        'scripts/preprocess_real_data.py',
        '--reads-bam', dataset_cfg['reads_bam'],
        '--reference-fasta', dataset_cfg['reference_fasta'],
        '--output-dir', str(output_dir),
        '--window-size', str(stage_cfg['window_size']),
        '--window-overlap', str(stage_cfg['window_overlap']),
        '--min-window-size', str(stage_cfg['min_window_size']),
        '--max-supports', str(stage_cfg['max_supports']),
        '--min-supports-per-window', str(stage_cfg['min_supports_per_window']),
        '--min-mapq', str(stage_cfg['min_mapq']),
        '--min-read-length', str(stage_cfg['min_read_length']),
        '--max-deletion-length', str(stage_cfg.get('max_deletion_length', 4)),
        '--train-contigs', dataset_cfg['train_contigs'],
        '--val-contigs', dataset_cfg['val_contigs'],
        '--test-contigs', dataset_cfg['test_contigs'],
    ]
    train_set = {token.strip() for token in dataset_cfg['train_contigs'].split(',') if token.strip()}
    val_set = {token.strip() for token in dataset_cfg['val_contigs'].split(',') if token.strip()}
    test_set = {token.strip() for token in dataset_cfg['test_contigs'].split(',') if token.strip()}
    if (train_set & (val_set | test_set)) or (val_set & test_set):
        cmd += ['--allow-shared-holdout-contigs']
    if stage_cfg.get('max_examples_per_split'):
        cmd += ['--max-examples-per-split', str(stage_cfg['max_examples_per_split'])]
    if dataset_cfg.get('truth_vcf'):
        cmd += ['--truth-vcf', dataset_cfg['truth_vcf']]
    if dataset_cfg.get('phased_vcf'):
        cmd += ['--phased-vcf', dataset_cfg['phased_vcf']]
    if dataset_cfg.get('confident_bed'):
        cmd += ['--confident-bed', dataset_cfg['confident_bed']]
    if dataset_cfg.get('haplotagged_bam'):
        cmd += ['--haplotagged-bam', dataset_cfg['haplotagged_bam']]
    for region_name, region_path in profile.get('region_beds', {}).items():
        if region_path:
            cmd += ['--region-bed', f'{region_name}={region_path}']
    return cmd


def build_config(stage_cfg, dataset_dir, checkpoint_dir, manifest_path, region_names, support_mode, init_checkpoint='', checkpoint_weights=None):
    checkpoint_weights = checkpoint_weights or profile['checkpoint_weights']
    effective_batch_size = 1 if RESOLVED_DEVICE == 'mps' else stage_cfg['batch_size']
    return {
        'model': {
            'd_model': 64,
            'num_heads': 4,
            'num_layers': 2,
            'ff_mult': 2,
            'dropout': 0.1,
            'target_feature_dim': 10,
            'support_feature_dim': 17,
            'max_supports': stage_cfg['max_supports'],
            'max_insertions_per_pos': 2,
            'max_deletion_length': stage_cfg.get('max_deletion_length', 4),
            'run_length_classes': 8,
            'conv_kernel_size': 5,
            'support_mode': support_mode,
            'apply_hard_edit_support_filter': True,
            'hard_edit_min_support_agreement': 0.975,
            'hard_edit_max_support_entropy': 0.10,
            'hard_edit_min_support_depth': max(2.0, float(stage_cfg['min_supports_per_window'])),
            'hard_edit_filter_logit_bias': 8.0,
            'inference_hard_edit_confidence_threshold': 0.95,
            'inference_hard_edit_temperature': 0.65,
            'inference_sub_confidence_threshold': 0.90,
            'inference_del_confidence_threshold': 0.97,
            'inference_ins_confidence_threshold': 0.85,
            'deletion_commit_trust_threshold': 0.92,
            'deletion_candidate_threshold': 0.92,
            'inference_use_deletion_consistency_check': True,
        },
        'data': {
            'train_path': safe_rel(dataset_dir / 'train.jsonl'),
            'val_path': safe_rel(dataset_dir / 'val.jsonl'),
            'test_path': safe_rel(dataset_dir / 'test.jsonl'),
            'manifest_path': safe_rel(manifest_path),
            'max_target_len': stage_cfg['max_target_len'],
            'max_supports': stage_cfg['max_supports'],
            'max_support_len': stage_cfg['max_support_len'],
            'num_workers': 0,
            'deletion_oversample_weight': 2.5,
            'region_names': sorted(region_names),
        },
        'train': {
            'seed': 42,
            'batch_size': effective_batch_size,
            'epochs': stage_cfg['epochs'],
            'lr': 1e-4,
            'weight_decay': 0.01,
            'grad_clip_norm': 0.5,
            'device': RESOLVED_DEVICE,
            'mixed_precision': RESOLVED_MIXED_PRECISION,
            'log_every': 20,
            'eval_every': 1,
            'save_dir': safe_rel(checkpoint_dir),
            'init_checkpoint': init_checkpoint,
            'checkpoint_metric': 'composite_sequence',
            'checkpoint_metric_mode': 'max',
            'checkpoint_overcorrection_weight': checkpoint_weights.get('overcorrection', 0.0),
            'checkpoint_hard_edit_fp_weight': checkpoint_weights.get('hard_edit_fp', 0.0),
            'checkpoint_length_ratio_weight': checkpoint_weights.get('length_ratio', 0.0),
            'early_stopping_patience': stage_cfg.get('early_stopping_patience', 0),
            'oversample_deletion_windows': True,
        },
        'loss': {
            'lambda_edit': 1.0,
            'lambda_sequence': 0.5,
            'lambda_length': 0.3,
            'lambda_insertion_count': 0.2,
            'lambda_trust': 0.1,
            'lambda_hard_edit': 0.5,
            'lambda_hard_edit_precision': 1.2,
            'lambda_selective_hard_edit': 0.2,
            'lambda_deletion_candidate': 0.4,
            'lambda_deletion_length': 0.2,
            'lambda_run_length_aux': 0.1,
            'lambda_deletion_positive_reward': 0.15,
            'lambda_support': 0.0,
            'lambda_preserve': 0.2,
            'lambda_uncertainty': 0.1,
            'homopolymer_weight_scale': 0.15,
            'label_smoothing': 0.0,
            'edit_class_weights': [],
            'auto_edit_class_weights': True,
            'edit_class_weight_power': 1.0,
            'edit_class_weight_count_smoothing': 1.0,
            'edit_class_weight_min': 0.25,
            'edit_class_weight_max': 8.0,
            'substitution_loss_scale': 1.5,
            'deletion_loss_scale': 1.5,
            'insertion_loss_scale': 1.1,
            'hard_edit_uncertainty_power': 2.5,
            'hard_edit_entropy_threshold': 0.10,
            'hard_edit_agreement_threshold': 0.975,
            'hard_edit_entropy_scale': 4.0,
            'hard_edit_low_agreement_scale': 5.0,
            'hard_edit_false_positive_weight': 12.0,
            'hard_edit_false_negative_weight': 1.0,
            'selective_hard_edit_confidence_threshold': 0.6,
            'selective_hard_edit_uncertainty_threshold': 0.4,
            'selective_hard_edit_min_support_agreement': 0.97,
            'deletion_focal_gamma': 2.0,
            'deletion_false_positive_weight': 12.0,
            'deletion_false_negative_weight': 1.0,
            'deletion_positive_reward_scale': 1.5,
        },
    }


def selection_weights_for_profile(profile):
    weights = dict(profile.get('checkpoint_weights', {}))
    if EXPERIMENT_PRESET == 'hg002_chr20_small_benchmark':
        weights['overcorrection'] = max(1.0, float(weights.get('overcorrection', 0.0)))
        weights['hard_edit_fp'] = 0.0
        weights['length_ratio'] = 0.0
    return weights


def eval_targets_for_train_dataset(train_dataset_cfg):
    if EXPERIMENT_PRESET == 'hg002_chr20_small_benchmark':
        return [train_dataset_cfg]
    if train_dataset_cfg['name'] == PRIMARY_DATASET['name']:
        return EVAL_DATASETS
    return [train_dataset_cfg]


def baseline_targets_for_train_dataset(train_dataset_cfg):
    if EXPERIMENT_PRESET == 'hg002_chr20_small_benchmark':
        return [train_dataset_cfg]
    return eval_targets_for_train_dataset(train_dataset_cfg)


preprocess_plans = []
train_plans = []
eval_plans = []
baseline_plans = []
external_baseline_plans = []
downstream_plans = []
selection_weights = selection_weights_for_profile(profile)

for stage_idx, stage_cfg in enumerate(profile['stages']):
    stage_name = stage_cfg['name']
    previous_stage_name = profile['stages'][stage_idx - 1]['name'] if stage_idx > 0 else None
    stage_dirs = {}
    stage_manifest_paths = {}

    for dataset_cfg in ACTIVE_EVAL_DATASETS:
        if profile['mode'] == 'preprocessed_dataset':
            dataset_stage_dir = Path(dataset_cfg['train_path']).resolve().parent
            manifest_path = Path(dataset_cfg['manifest_path']).resolve()
        else:
            dataset_stage_dir = RUN_ROOT / dataset_cfg['name'] / stage_name
            dataset_stage_dir.mkdir(parents=True, exist_ok=True)
            manifest_path = dataset_stage_dir / 'manifest.json'
            preprocess_plans.append({
                'stage': stage_name,
                'dataset': dataset_cfg['name'],
                'coverage': dataset_cfg.get('coverage_tag', ''),
                'role': dataset_cfg['role'],
                'manifest_path': str(manifest_path),
                'cmd': build_preprocess_command(dataset_cfg, stage_cfg, dataset_stage_dir),
            })
        stage_dirs[dataset_cfg['name']] = dataset_stage_dir
        stage_manifest_paths[dataset_cfg['name']] = manifest_path

    region_names = set(profile.get('region_beds', {}).keys()) | {'homopolymer', 'variant_rich', 'tandem_repeat'}

    for train_dataset_cfg in ACTIVE_TRAIN_DATASETS:
        coverage_tag = train_dataset_cfg.get('coverage_tag', train_dataset_cfg['name'])
        train_stage_dir = stage_dirs[train_dataset_cfg['name']]
        eval_targets = eval_targets_for_train_dataset(train_dataset_cfg)
        baseline_targets = baseline_targets_for_train_dataset(train_dataset_cfg)
        stage_output_dir = OUT_ROOT / coverage_tag / stage_name
        stage_output_dir.mkdir(parents=True, exist_ok=True)

        for run in SELECTED_MODEL_RUNS:
            checkpoint_dir = CKPT_ROOT / coverage_tag / stage_name / run['name']
            checkpoint_dir.mkdir(parents=True, exist_ok=True)
            config_path = CONFIG_ROOT / f'{coverage_tag}_{stage_name}_{run["name"]}.yaml'
            init_checkpoint = ''
            if previous_stage_name is not None:
                init_checkpoint = safe_rel(CKPT_ROOT / coverage_tag / previous_stage_name / run['name'] / 'best_model.pt')
            cfg = build_config(
                stage_cfg,
                train_stage_dir,
                checkpoint_dir,
                stage_manifest_paths[train_dataset_cfg['name']],
                region_names,
                support_mode=run['support_mode'],
                init_checkpoint=init_checkpoint,
                checkpoint_weights=selection_weights,
            )
            with open(config_path, 'w', encoding='utf-8') as handle:
                yaml.safe_dump(cfg, handle, sort_keys=False)
            train_plans.append({
                'coverage': coverage_tag,
                'stage': stage_name,
                'train_dataset': train_dataset_cfg['name'],
                'run': run['name'],
                'config_path': str(config_path),
                'checkpoint_dir': str(checkpoint_dir),
                'cmd': [sys.executable, 'scripts/train.py', '--config', str(config_path)],
            })

            if stage_idx == len(profile['stages']) - 1:
                for dataset_cfg in eval_targets:
                    dataset_stage_dir = stage_dirs[dataset_cfg['name']]
                    dataset_output_dir = stage_output_dir / dataset_cfg['name'] / run['name']
                    dataset_output_dir.mkdir(parents=True, exist_ok=True)
                    eval_plans.append({
                        'coverage': coverage_tag,
                        'train_dataset': train_dataset_cfg['name'],
                        'stage': stage_name,
                        'dataset': dataset_cfg['name'],
                        'run': run['name'],
                        'summary_path': str(dataset_output_dir / 'test_summary.json'),
                        'predictions_path': str(dataset_output_dir / 'test_predictions.jsonl'),
                        'cmd': [
                            sys.executable, 'scripts/test.py', '--config', str(config_path),
                            '--checkpoint', str(checkpoint_dir / 'best_model.pt'),
                            '--data-path', str(Path(dataset_cfg['test_path']).resolve() if profile['mode'] == 'preprocessed_dataset' else dataset_stage_dir / 'test.jsonl'),
                            '--summary-out', str(dataset_output_dir / 'test_summary.json'),
                            '--predictions-out', str(dataset_output_dir / 'test_predictions.jsonl'),
                        ],
                    })

                if run['name'] == PRIMARY_ANALYSIS_RUN:
                    for dataset_cfg in baseline_targets:
                        dataset_stage_dir = stage_dirs[dataset_cfg['name']]
                        baseline_out = stage_output_dir / dataset_cfg['name'] / 'baselines'
                        baseline_out.mkdir(parents=True, exist_ok=True)
                        baseline_plans.extend([
                            {
                                'kind': 'internal',
                                'coverage': coverage_tag,
                                'train_dataset': train_dataset_cfg['name'],
                                'baseline': 'no_edit',
                                'dataset': dataset_cfg['name'],
                                'summary_path': str(baseline_out / 'no_edit_summary.json'),
                                'cmd': [sys.executable, 'scripts/no_edit_baseline.py', '--config', str(config_path), '--data-path', str(Path(dataset_cfg['test_path']).resolve() if profile['mode'] == 'preprocessed_dataset' else dataset_stage_dir / 'test.jsonl'), '--summary-out', str(baseline_out / 'no_edit_summary.json'), '--predictions-out', str(baseline_out / 'no_edit_predictions.jsonl')],
                            },
                            {
                                'kind': 'internal',
                                'coverage': coverage_tag,
                                'train_dataset': train_dataset_cfg['name'],
                                'baseline': 'consensus',
                                'dataset': dataset_cfg['name'],
                                'summary_path': str(baseline_out / 'consensus_summary.json'),
                                'cmd': [sys.executable, 'scripts/consensus_baseline.py', '--config', str(config_path), '--data-path', str(Path(dataset_cfg['test_path']).resolve() if profile['mode'] == 'preprocessed_dataset' else dataset_stage_dir / 'test.jsonl'), '--summary-out', str(baseline_out / 'consensus_summary.json'), '--predictions-out', str(baseline_out / 'consensus_predictions.jsonl')],
                            },
                        ])

                    if train_dataset_cfg['name'] == PRIMARY_DATASET['name']:
                        for dataset_cfg in eval_targets:
                            external_out = stage_output_dir / dataset_cfg['name'] / 'external_baselines'
                            external_out.mkdir(parents=True, exist_ok=True)
                            for tool in ['herro', 'dechat']:
                                external_baseline_plans.append({
                                    'coverage': coverage_tag,
                                    'tool': tool,
                                    'dataset': dataset_cfg['name'],
                                    'summary_path': str(external_out / f'{tool}_summary.json'),
                                    'cmd': [sys.executable, 'scripts/run_external_baseline.py', '--tool', tool, '--reads-bam', dataset_cfg['reads_bam'], '--reference-fasta', dataset_cfg['reference_fasta'], '--output-dir', str(external_out / tool), '--summary-out', str(external_out / f'{tool}_summary.json')],
                                })

                        for dataset_cfg in eval_targets:
                            eval_row = next(row for row in eval_plans if row['coverage'] == coverage_tag and row['dataset'] == dataset_cfg['name'] and row['run'] == PRIMARY_ANALYSIS_RUN)
                            downstream_out = stage_output_dir / dataset_cfg['name'] / 'downstream'
                            downstream_out.mkdir(parents=True, exist_ok=True)
                            corrected_fasta = downstream_out / 'corrected_reads.fasta'
                            downstream_plans.extend([
                                {
                                    'kind': 'export',
                                    'coverage': coverage_tag,
                                    'dataset': dataset_cfg['name'],
                                    'summary_path': str(downstream_out / 'export_summary.json'),
                                    'cmd': [sys.executable, 'scripts/export_predictions_to_fastx.py', '--predictions-jsonl', eval_row['predictions_path'], '--output', str(corrected_fasta), '--format', 'fasta'],
                                },
                                {
                                    'kind': 'assembly',
                                    'coverage': coverage_tag,
                                    'dataset': dataset_cfg['name'],
                                    'summary_path': str(downstream_out / 'assembly_summary.json'),
                                    'cmd': [sys.executable, 'scripts/run_assembly_eval.py', '--reads-fastx', str(corrected_fasta), '--reference-fasta', dataset_cfg['reference_fasta'], '--output-dir', str(downstream_out / 'assembly'), '--summary-out', str(downstream_out / 'assembly_summary.json')],
                                },
                                {
                                    'kind': 'variant_eval',
                                    'coverage': coverage_tag,
                                    'dataset': dataset_cfg['name'],
                                    'summary_path': str(downstream_out / 'variant_eval_summary.json'),
                                    'cmd': [sys.executable, 'scripts/run_variant_eval.py', '--reads-fastx', str(corrected_fasta), '--reference-fasta', dataset_cfg['reference_fasta'], '--truth-vcf', dataset_cfg['truth_vcf'], '--confident-bed', dataset_cfg['confident_bed'], '--output-dir', str(downstream_out / 'variant_eval'), '--summary-out', str(downstream_out / 'variant_eval_summary.json')],
                                },
                            ])

benchmark_plan = {
    'preset': EXPERIMENT_PRESET,
    'selected_runs': SELECTED_RUNS,
    'device': RESOLVED_DEVICE,
    'mixed_precision': RESOLVED_MIXED_PRECISION,
    'selection_weights': selection_weights,
    'profile': profile,
    'preprocess_plans': preprocess_plans,
    'train_plans': train_plans,
    'eval_plans': eval_plans,
    'baseline_plans': baseline_plans,
    'external_baseline_plans': external_baseline_plans,
    'downstream_plans': downstream_plans,
}
PLAN_PATH.write_text(json.dumps(benchmark_plan, indent=2))
display(pd.DataFrame(train_plans))
print('plan written to', PLAN_PATH)
# Out:
#   coverage        stage            train_dataset   run  \
# 0       8x  chr20_small   hg002_chr20_primary_8x  full
# 1      12x  chr20_small  hg002_chr20_primary_12x  full
# 2      20x  chr20_small  hg002_chr20_primary_20x  full
#
#                                          config_path  \
# 0  /Users/shanejayasundera/LRS-Error-Correction/c...
# 1  /Users/shanejayasundera/LRS-Error-Correction/c...
# 2  /Users/shanejayasundera/LRS-Error-Correction/c...
#
#                                       checkpoint_dir  \
# 0  /Users/shanejayasundera/LRS-Error-Correction/c...
# 1  /Users/shanejayasundera/LRS-Error-Correction/c...
# 2  /Users/shanejayasundera/LRS-Error-Correction/c...
#
#                                                  cmd
# 0  [/Users/shanejayasundera/anaconda3/envs/lrs_er...
# 1  [/Users/shanejayasundera/anaconda3/envs/lrs_er...
# 2  [/Users/shanejayasundera/anaconda3/envs/lrs_er...
# plan written to /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/benchmark_plan.json

# %%
env = os.environ.copy()
env['PYTHONPATH'] = str(ROOT / 'src')
env['PYTHONUNBUFFERED'] = '1'
env.setdefault('PYTORCH_ENABLE_MPS_FALLBACK', '1')
FORCE_PREPROCESS = os.environ.get('OMEGA_FORCE_PREPROCESS', '0').strip() in {'1', 'true', 'TRUE', 'yes', 'YES'}
AUTO_PREPROCESS = profile['mode'] != 'preprocessed_dataset' and any([RUN_TRAIN, RUN_TEST, RUN_BASELINES, RUN_EXTERNAL_BASELINES, RUN_DOWNSTREAM])
EFFECTIVE_RUN_PREPROCESS = RUN_PREPROCESS or AUTO_PREPROCESS or FORCE_PREPROCESS
if AUTO_PREPROCESS and not RUN_PREPROCESS:
    print('auto-enabling preprocess because this preset requires derived JSONL datasets before train/test/baselines')
if FORCE_PREPROCESS:
    print('forcing preprocess because OMEGA_FORCE_PREPROCESS is enabled')
missing_required = missing_required_inputs(validation_rows)
if any([EFFECTIVE_RUN_PREPROCESS, RUN_TRAIN, RUN_TEST, RUN_BASELINES, RUN_EXTERNAL_BASELINES, RUN_DOWNSTREAM]) and missing_required:
    raise FileNotFoundError('Cannot execute benchmark because required inputs are missing:\n' + pd.DataFrame(missing_required).to_string(index=False))

def preprocess_outputs_ready(row):
    manifest_path = Path(row['manifest_path'])
    output_dir = manifest_path.parent
    required = [manifest_path, output_dir / 'train.jsonl', output_dir / 'val.jsonl', output_dir / 'test.jsonl']
    return all(path.exists() and path.stat().st_size > 0 for path in required)

if EFFECTIVE_RUN_PREPROCESS:
    if profile['mode'] == 'local_fastq_demo':
        for stage_cfg in profile['stages']:
            stage_dir = RUN_ROOT / PRIMARY_DATASET['name'] / stage_cfg['name']
            manifest = prepare_demo_stage(profile, stage_cfg, stage_dir)
            print(json.dumps(manifest, indent=2))
    else:
        for row in preprocess_plans:
            if not FORCE_PREPROCESS and preprocess_outputs_ready(row):
                print(f'\n=== preprocess {row["stage"]} / {row["dataset"]} ===')
                print(f'skipping preprocess; found existing dataset at {Path(row["manifest_path"]).parent}')
                continue
            print(f'\n=== preprocess {row["stage"]} / {row["dataset"]} ===')
            run_cmd(row['cmd'], env=env)

if RUN_TRAIN:
    for row in train_plans:
        print(f'\n=== train {row["stage"]} / {row["run"]} ===')
        run_cmd(row['cmd'], env=env)

if RUN_TEST:
    for row in eval_plans:
        print(f'\n=== test {row["dataset"]} / {row["run"]} ===')
        run_cmd(row['cmd'], env=env)

if RUN_BASELINES:
    for row in baseline_plans:
        print(f'\n=== baseline {row["baseline"]} / {row["dataset"]} ===')
        run_cmd(row['cmd'], env=env)

if RUN_EXTERNAL_BASELINES:
    for row in external_baseline_plans:
        print(f'\n=== external {row["tool"]} / {row["dataset"]} ===')
        run_cmd(row['cmd'], env=env)

if RUN_DOWNSTREAM:
    for row in downstream_plans:
        print(f'\n=== downstream {row["kind"]} / {row["dataset"]} ===')
        run_cmd(row['cmd'], env=env)
# Out:
# auto-enabling preprocess because this preset requires derived JSONL datasets before train/test/baselines
#
# === preprocess chr20_small / hg002_chr20_primary_8x ===
# skipping preprocess; found existing dataset at /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_8x/chr20_small
#
# === preprocess chr20_small / hg002_chr20_primary_12x ===
# skipping preprocess; found existing dataset at /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_12x/chr20_small
#
# === preprocess chr20_small / hg002_chr20_primary_20x ===
# skipping preprocess; found existing dataset at /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_20x/chr20_small
#
# === train chr20_small / full ===
# /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/train.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/8x_chr20_small_full.yaml
# python(21391) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# /Users/shanejayasundera/LRS-Error-Correction/scripts/train.py:249: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=cfg.train.mixed_precision and device.type == "cuda")
# resolved edit class weights:
# [
#   {
#     "token_id": 0,
#     "token": "COPY",
#     "weight": 0.25
#   },
#   {
#     "token_id": 1,
#     "token": "SUB_A",
#     "weight": 8.0
#   },
#   {
#     "token_id": 2,
#     "token": "SUB_C",
#     "weight": 8.0
#   },
#   {
#     "token_id": 3,
#     "token": "SUB_G",
#     "weight": 8.0
#   },
#   {
#     "token_id": 4,
#     "token": "SUB_T",
#     "weight": 8.0
#   },
#   {
#     "token_id": 5,
#     "token": "DEL",
#     "weight": 3.66989803314209
#   },
#   {
#     "token_id": 6,
#     "token": "INS_A",
#     "weight": 8.0
#   },
#   {
#     "token_id": 7,
#     "token": "INS_C",
#     "weight": 8.0
#   },
#   {
#     "token_id": 8,
#     "token": "INS_G",
#     "weight": 8.0
#   },
#   {
#     "token_id": 9,
#     "token": "INS_T",
#     "weight": 8.0
#   },
#   {
#     "token_id": 10,
#     "token": "PAD",
#     "weight": 0.0
#   }
# ]
# epoch 1/7
# /Users/shanejayasundera/LRS-Error-Correction/scripts/train.py:131: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast(enabled=cfg.train.mixed_precision and device.type == "cuda"):
# train step=20: {"loss": 12.105276703834534, "edit_loss": 1.9012135952711104, "sequence_loss": 1.3717271089553833, "length_loss": 0.19280574154108762, "insertion_count_loss": 0.7585849314928055, "trust_loss": 0.5522658869624137, "hard_edit_loss": 0.0006610006002517821, "hard_edit_precision_loss": 6.0939302206039425, "selective_hard_edit_loss": 2.4958433508872986, "deletion_candidate_loss": 1.2526442736387253, "deletion_length_loss": 1.694525808095932, "deletion_positive_reward_loss": 0.770570918917656, "run_length_loss": 2.105379331111908, "hard_edit_entropy_excess_mean": 0.011481682187877595, "hard_edit_agreement_deficit_mean": 0.012702580890618265, "support_loss": 2.2909328818321226, "preserve_loss": 0.8335250169038773, "uncertainty_loss": 1.0840717017650605, "predicted_length": 2305.416925048828, "target_length": 1940.45, "predicted_insertions": 1478.2175689697265, "target_insertions": 8.0, "trust_gate_mean": 0.5967116236686707, "support_confidence_mean": 0.9082088112831116, "support_uncertainty_mean": 0.05411391733214259, "selective_hard_edit_fraction": 0.02279488891363144}
# train step=40: {"loss": 9.570049524307251, "edit_loss": 2.1398524433374404, "sequence_loss": 1.3408320367336273, "length_loss": 0.09514974495618844, "insertion_count_loss": 0.7151467144489289, "trust_loss": 0.4460235252976418, "hard_edit_loss": 0.00027696811009718657, "hard_edit_precision_loss": 3.9762349128723145, "selective_hard_edit_loss": 3.1262335658073424, "deletion_candidate_loss": 0.7120012789964676, "deletion_length_loss": 1.432827877998352, "deletion_positive_reward_loss": 0.8673105806112289, "run_length_loss": 1.976006317138672, "hard_edit_entropy_excess_mean": 0.011827123234979808, "hard_edit_agreement_deficit_mean": 0.01333208626601845, "support_loss": 2.0251511514186857, "preserve_loss": 0.8033443212509155, "uncertainty_loss": 0.8700505018234252, "predicted_length": 2132.691339111328, "target_length": 1972.45, "predicted_insertions": 1407.2063720703125, "target_insertions": 3.8, "trust_gate_mean": 0.6949414104223252, "support_confidence_mean": 0.9061295300722122, "support_uncertainty_mean": 0.05528377201408148, "selective_hard_edit_fraction": 0.0390380859375}
# train step=60: {"loss": 8.284894442558288, "edit_loss": 2.760683587193489, "sequence_loss": 1.2969621956348418, "length_loss": 0.10222377688623965, "insertion_count_loss": 0.6579136669635772, "trust_loss": 0.3301968455314636, "hard_edit_loss": 0.00012563912378240615, "hard_edit_precision_loss": 2.503449410200119, "selective_hard_edit_loss": 3.4939252138137817, "deletion_candidate_loss": 0.37679456919431686, "deletion_length_loss": 1.4366520404815675, "deletion_positive_reward_loss": 1.0050965070724487, "run_length_loss": 1.77786346077919, "hard_edit_entropy_excess_mean": 0.010157879558391869, "hard_edit_agreement_deficit_mean": 0.013223123899661005, "support_loss": 1.7541494190692901, "preserve_loss": 0.7391152739524841, "uncertainty_loss": 0.6305086016654968, "predicted_length": 1866.2993408203124, "target_length": 1921.85, "predicted_insertions": 1235.73212890625, "target_insertions": 6.65, "trust_gate_mean": 0.7848363578319549, "support_confidence_mean": 0.928753599524498, "support_uncertainty_mean": 0.042951496038585904, "selective_hard_edit_fraction": 0.053430818021297455}
# train step=80: {"loss": 6.273364913463593, "edit_loss": 2.071425759792328, "sequence_loss": 1.1493613719940186, "length_loss": 0.03610086865955964, "insertion_count_loss": 0.5884322017431259, "trust_loss": 0.3463355116546154, "hard_edit_loss": 0.00015163878446244894, "hard_edit_precision_loss": 1.5074627459049226, "selective_hard_edit_loss": 4.130917000770569, "deletion_candidate_loss": 0.17976676672697067, "deletion_length_loss": 1.327665251493454, "deletion_positive_reward_loss": 1.09887575507164, "run_length_loss": 1.603453367948532, "hard_edit_entropy_excess_mean": 0.01221663854084909, "hard_edit_agreement_deficit_mean": 0.013493356294929981, "support_loss": 1.3299963891506195, "preserve_loss": 0.6368057817220688, "uncertainty_loss": 0.38916040360927584, "predicted_length": 1972.4588684082032, "target_length": 2032.9, "predicted_insertions": 1207.3075012207032, "target_insertions": 11.15, "trust_gate_mean": 0.8525867193937302, "support_confidence_mean": 0.893290302157402, "support_uncertainty_mean": 0.061945813102647664, "selective_hard_edit_fraction": 0.022802734375}
# train step=100: {"loss": 4.600954842567444, "edit_loss": 1.3741439417004586, "sequence_loss": 0.8848447650671005, "length_loss": 0.0531977747566998, "insertion_count_loss": 0.5039701759815216, "trust_loss": 0.30154396444559095, "hard_edit_loss": 8.303384282761783e-05, "hard_edit_precision_loss": 0.8838965326547623, "selective_hard_edit_loss": 4.509226429462433, "deletion_candidate_loss": 0.08792539983987809, "deletion_length_loss": 1.0753192812204362, "deletion_positive_reward_loss": 1.09487344622612, "run_length_loss": 1.4736584365367889, "hard_edit_entropy_excess_mean": 0.012920354679226875, "hard_edit_agreement_deficit_mean": 0.01182200196199119, "support_loss": 0.8215349733829498, "preserve_loss": 0.45214356631040575, "uncertainty_loss": 0.22658359929919242, "predicted_length": 2133.494104003906, "target_length": 2026.85, "predicted_insertions": 1024.6116729736327, "target_insertions": 4.4, "trust_gate_mean": 0.8924581706523895, "support_confidence_mean": 0.910057333111763, "support_uncertainty_mean": 0.054319639923051, "selective_hard_edit_fraction": 0.0149658203125}
# train step=120: {"loss": 5.7557053565979, "edit_loss": 2.6514521867036818, "sequence_loss": 0.6403771713376045, "length_loss": 0.09977763164788485, "insertion_count_loss": 0.34707176834344866, "trust_loss": 0.26639389283955095, "hard_edit_loss": 4.109827224780815e-05, "hard_edit_precision_loss": 0.8568576842546463, "selective_hard_edit_loss": 4.876622605323791, "deletion_candidate_loss": 0.05914809051901102, "deletion_length_loss": 1.245670846104622, "deletion_positive_reward_loss": 1.2013387203216552, "run_length_loss": 1.4013778626918794, "hard_edit_entropy_excess_mean": 0.009462121175602078, "hard_edit_agreement_deficit_mean": 0.012720393319614231, "support_loss": 0.48765973299741744, "preserve_loss": 0.2363109238445759, "uncertainty_loss": 0.141092137619853, "predicted_length": 2171.7224243164064, "target_length": 1987.45, "predicted_insertions": 696.3006011962891, "target_insertions": 8.65, "trust_gate_mean": 0.9083938032388688, "support_confidence_mean": 0.9224558532238006, "support_uncertainty_mean": 0.0455656454898417, "selective_hard_edit_fraction": 0.0392822265625}
# train step=140: {"loss": 4.505672097206116, "edit_loss": 1.8356785774230957, "sequence_loss": 0.4356750279664993, "length_loss": 0.05264196079224348, "insertion_count_loss": 0.2255212090909481, "trust_loss": 0.22490489333868027, "hard_edit_loss": 1.791832227056034e-05, "hard_edit_precision_loss": 0.6683136969804764, "selective_hard_edit_loss": 4.987591075897217, "deletion_candidate_loss": 0.04255650825798511, "deletion_length_loss": 1.0586805015802383, "deletion_positive_reward_loss": 1.154376393556595, "run_length_loss": 1.2761599123477936, "hard_edit_entropy_excess_mean": 0.00904147924738936, "hard_edit_agreement_deficit_mean": 0.009780194098129868, "support_loss": 0.3426446981728077, "preserve_loss": 0.15364115908741952, "uncertainty_loss": 0.09005817882716656, "predicted_length": 2071.439068603516, "target_length": 1968.2, "predicted_insertions": 449.8322692871094, "target_insertions": 4.95, "trust_gate_mean": 0.9197558164596558, "support_confidence_mean": 0.9407845854759216, "support_uncertainty_mean": 0.036099298018962146, "selective_hard_edit_fraction": 0.02205539643764496}
# train step=160: {"loss": 4.69536384344101, "edit_loss": 2.0755134165287017, "sequence_loss": 0.3628487542271614, "length_loss": 0.03140094082336873, "insertion_count_loss": 0.1532857406884432, "trust_loss": 0.28579734787344935, "hard_edit_loss": 3.668274231891644e-05, "hard_edit_precision_loss": 0.6651457011699676, "selective_hard_edit_loss": 5.032718443870545, "deletion_candidate_loss": 0.035580215975642204, "deletion_length_loss": 1.0548590630292893, "deletion_positive_reward_loss": 1.1736008822917938, "run_length_loss": 1.3235207855701447, "hard_edit_entropy_excess_mean": 0.013648879970423878, "hard_edit_agreement_deficit_mean": 0.01311628483235836, "support_loss": 0.3274309054017067, "preserve_loss": 0.12393529899418354, "uncertainty_loss": 0.06648934930562973, "predicted_length": 2071.5366455078124, "target_length": 2011.0, "predicted_insertions": 315.40771636962893, "target_insertions": 6.85, "trust_gate_mean": 0.9317306637763977, "support_confidence_mean": 0.9169630616903305, "support_uncertainty_mean": 0.051125029334798455, "selective_hard_edit_fraction": 0.02548828125}
# train step=180: {"loss": 4.653014707565307, "edit_loss": 2.0134050622582436, "sequence_loss": 0.334551976621151, "length_loss": 0.0427322031762742, "insertion_count_loss": 0.1208349883556366, "trust_loss": 0.24054351896047593, "hard_edit_loss": 2.135363313975347e-05, "hard_edit_precision_loss": 0.725526762008667, "selective_hard_edit_loss": 4.865647959709167, "deletion_candidate_loss": 0.03459674986079335, "deletion_length_loss": 1.131099908053875, "deletion_positive_reward_loss": 1.231358289718628, "run_length_loss": 1.1291870206594468, "hard_edit_entropy_excess_mean": 0.012025834823725745, "hard_edit_agreement_deficit_mean": 0.013305188063532114, "support_loss": 0.2814693868160248, "preserve_loss": 0.11812792122364044, "uncertainty_loss": 0.062135299295187, "predicted_length": 2053.7341064453126, "target_length": 1985.8, "predicted_insertions": 244.5273880004883, "target_insertions": 6.1, "trust_gate_mean": 0.9210034817457199, "support_confidence_mean": 0.9326642364263534, "support_uncertainty_mean": 0.042047243425622584, "selective_hard_edit_fraction": 0.0333984375}
# train step=200: {"loss": 4.769951844215393, "edit_loss": 2.2040686324238776, "sequence_loss": 0.2960102289915085, "length_loss": 0.01958461261065274, "insertion_count_loss": 0.09931995756924153, "trust_loss": 0.19267521239817142, "hard_edit_loss": 1.0469458969453171e-05, "hard_edit_precision_loss": 0.7173690021038055, "selective_hard_edit_loss": 4.853222060203552, "deletion_candidate_loss": 0.03924321476370096, "deletion_length_loss": 0.967459712922573, "deletion_positive_reward_loss": 1.2847886025905608, "run_length_loss": 1.1464302867650986, "hard_edit_entropy_excess_mean": 0.012211674172431231, "hard_edit_agreement_deficit_mean": 0.014849425270222127, "support_loss": 0.2725721254944801, "preserve_loss": 0.09375058393925428, "uncertainty_loss": 0.06077972836792469, "predicted_length": 2058.109210205078, "target_length": 2022.9, "predicted_insertions": 211.38622970581054, "target_insertions": 10.5, "trust_gate_mean": 0.9225604593753814, "support_confidence_mean": 0.9511263400316239, "support_uncertainty_mean": 0.03320378009229898, "selective_hard_edit_fraction": 0.024365234375}
# train step=220: {"loss": 4.1801722049713135, "edit_loss": 1.7893921092152596, "sequence_loss": 0.2578452743589878, "length_loss": 0.02954514785669744, "insertion_count_loss": 0.08681860566139221, "trust_loss": 0.2231364779174328, "hard_edit_loss": 2.5453949139375708e-05, "hard_edit_precision_loss": 0.6132169365882874, "selective_hard_edit_loss": 4.7460111618042, "deletion_candidate_loss": 0.032788189500570296, "deletion_length_loss": 1.0523763820528984, "deletion_positive_reward_loss": 1.2218732833862305, "run_length_loss": 1.0240361452102662, "hard_edit_entropy_excess_mean": 0.012271126080304385, "hard_edit_agreement_deficit_mean": 0.012116992357186973, "support_loss": 0.23288304805755616, "preserve_loss": 0.07316682636737823, "uncertainty_loss": 0.04332625744864345, "predicted_length": 2058.217010498047, "target_length": 2001.85, "predicted_insertions": 179.3785484313965, "target_insertions": 5.4, "trust_gate_mean": 0.9363971441984177, "support_confidence_mean": 0.9399128228425979, "support_uncertainty_mean": 0.03863272103480995, "selective_hard_edit_fraction": 0.02580642541870475}
# train step=240: {"loss": 3.804245150089264, "edit_loss": 1.3813126035034657, "sequence_loss": 0.22644868046045302, "length_loss": 0.01794646040216321, "insertion_count_loss": 0.08259459882974625, "trust_loss": 0.2972270015627146, "hard_edit_loss": 2.4557097588662204e-05, "hard_edit_precision_loss": 0.5847919374704361, "selective_hard_edit_loss": 4.915650391578675, "deletion_candidate_loss": 0.04246087074279785, "deletion_length_loss": 1.1442984983325004, "deletion_positive_reward_loss": 1.267572718858719, "run_length_loss": 1.1538094878196716, "hard_edit_entropy_excess_mean": 0.010993983200751244, "hard_edit_agreement_deficit_mean": 0.011481953947804869, "support_loss": 0.22611254528164865, "preserve_loss": 0.08482408411800861, "uncertainty_loss": 0.04864229075610638, "predicted_length": 1998.53720703125, "target_length": 1968.65, "predicted_insertions": 167.54750709533693, "target_insertions": 4.75, "trust_gate_mean": 0.9226867944002152, "support_confidence_mean": 0.9084381073713302, "support_uncertainty_mean": 0.05347682973369956, "selective_hard_edit_fraction": 0.020713881496340035}
# train step=260: {"loss": 5.317009854316711, "edit_loss": 2.4939177744090557, "sequence_loss": 0.3338931292295456, "length_loss": 0.055495843702919954, "insertion_count_loss": 0.09130695313215256, "trust_loss": 0.2859820529818535, "hard_edit_loss": 4.530937606901375e-05, "hard_edit_precision_loss": 0.9500220522284508, "selective_hard_edit_loss": 4.4947720766067505, "deletion_candidate_loss": 0.05288545098155737, "deletion_length_loss": 1.0790890753269196, "deletion_positive_reward_loss": 1.1803408682346344, "run_length_loss": 1.11077524125576, "hard_edit_entropy_excess_mean": 0.01075151371769607, "hard_edit_agreement_deficit_mean": 0.012556251883506776, "support_loss": 0.26299669668078424, "preserve_loss": 0.11582747027277947, "uncertainty_loss": 0.05367395114153624, "predicted_length": 2033.3665283203125, "target_length": 1961.5, "predicted_insertions": 182.62015914916992, "target_insertions": 5.55, "trust_gate_mean": 0.892975577712059, "support_confidence_mean": 0.9167966723442078, "support_uncertainty_mean": 0.049048703513108194, "selective_hard_edit_fraction": 0.0473388671875}
# train step=280: {"loss": 4.505386114120483, "edit_loss": 2.0813602436333896, "sequence_loss": 0.24824194945394992, "length_loss": 0.029264717489422765, "insertion_count_loss": 0.0668157609179616, "trust_loss": 0.32784955613315103, "hard_edit_loss": 6.884597890319811e-05, "hard_edit_precision_loss": 0.6947766676545143, "selective_hard_edit_loss": 4.425076091289521, "deletion_candidate_loss": 0.0346190613694489, "deletion_length_loss": 0.9935955673456192, "deletion_positive_reward_loss": 1.2793223917484284, "run_length_loss": 1.0345503300428391, "hard_edit_entropy_excess_mean": 0.010562965786084533, "hard_edit_agreement_deficit_mean": 0.013080255594104528, "support_loss": 0.21449117884039878, "preserve_loss": 0.0694596679881215, "uncertainty_loss": 0.04383562430739403, "predicted_length": 1986.0960021972655, "target_length": 1943.3, "predicted_insertions": 139.0131549835205, "target_insertions": 8.9, "trust_gate_mean": 0.9015529960393905, "support_confidence_mean": 0.8947174191474915, "support_uncertainty_mean": 0.06005907831713557, "selective_hard_edit_fraction": 0.031991955498233436}
# train step=300: {"loss": 4.717033410072327, "edit_loss": 1.9725635588169097, "sequence_loss": 0.29183613434433936, "length_loss": 0.01991770551630907, "insertion_count_loss": 0.08778704516589642, "trust_loss": 0.29450077302753924, "hard_edit_loss": 6.38499076529797e-05, "hard_edit_precision_loss": 1.008978869765997, "selective_hard_edit_loss": 4.129090249538422, "deletion_candidate_loss": 0.06560492021963, "deletion_length_loss": 0.8380863651633262, "deletion_positive_reward_loss": 1.1054084181785584, "run_length_loss": 1.084866186976433, "hard_edit_entropy_excess_mean": 0.00968000788707286, "hard_edit_agreement_deficit_mean": 0.011085550184361637, "support_loss": 0.2746476102620363, "preserve_loss": 0.1761679857969284, "uncertainty_loss": 0.05553500093519688, "predicted_length": 1955.3276977539062, "target_length": 1953.55, "predicted_insertions": 184.7278274536133, "target_insertions": 11.25, "trust_gate_mean": 0.865207490324974, "support_confidence_mean": 0.9177025079727172, "support_uncertainty_mean": 0.04804473957046866, "selective_hard_edit_fraction": 0.024902342027053236}
# train step=320: {"loss": 3.3478800117969514, "edit_loss": 1.1946838583797217, "sequence_loss": 0.177516221255064, "length_loss": 0.027971339330542834, "insertion_count_loss": 0.06068150196224451, "trust_loss": 0.21266770251095296, "hard_edit_loss": 2.682943217182654e-05, "hard_edit_precision_loss": 0.5618359133601188, "selective_hard_edit_loss": 4.120192813873291, "deletion_candidate_loss": 0.030930605717003345, "deletion_length_loss": 1.0076532661914825, "deletion_positive_reward_loss": 1.1929601371288299, "run_length_loss": 1.1113613039255141, "hard_edit_entropy_excess_mean": 0.009276659041643143, "hard_edit_agreement_deficit_mean": 0.009606104250997305, "support_loss": 0.17373374551534654, "preserve_loss": 0.08588854037225246, "uncertainty_loss": 0.032276352401822805, "predicted_length": 2016.576953125, "target_length": 1962.8, "predicted_insertions": 122.21958656311035, "target_insertions": 2.85, "trust_gate_mean": 0.9097511827945709, "support_confidence_mean": 0.9462785601615906, "support_uncertainty_mean": 0.03328708936460316, "selective_hard_edit_fraction": 0.020615004005958327}
# train step=340: {"loss": 4.107267656922341, "edit_loss": 1.8016296096146107, "sequence_loss": 0.1999449387192726, "length_loss": 0.01953103850828484, "insertion_count_loss": 0.05645315367728472, "trust_loss": 0.2512147217988968, "hard_edit_loss": 2.121723022465716e-05, "hard_edit_precision_loss": 0.6689027287065983, "selective_hard_edit_loss": 4.175078547000885, "deletion_candidate_loss": 0.03814524160698056, "deletion_length_loss": 1.1666693702340125, "deletion_positive_reward_loss": 1.076547908782959, "run_length_loss": 0.9945432394742966, "hard_edit_entropy_excess_mean": 0.018357263691723347, "hard_edit_agreement_deficit_mean": 0.019763650931417943, "support_loss": 0.2740478619933128, "preserve_loss": 0.057142102904617784, "uncertainty_loss": 0.04727659411728382, "predicted_length": 2058.128497314453, "target_length": 2021.35, "predicted_insertions": 123.85510025024413, "target_insertions": 9.55, "trust_gate_mean": 0.9131740093231201, "support_confidence_mean": 0.9273134291172027, "support_uncertainty_mean": 0.04921241234987974, "selective_hard_edit_fraction": 0.0202880859375}
# train step=360: {"loss": 3.4484124690294267, "edit_loss": 1.3864085165783764, "sequence_loss": 0.1611561171710491, "length_loss": 0.014358661900041625, "insertion_count_loss": 0.04991584699600935, "trust_loss": 0.25681319907307626, "hard_edit_loss": 3.6039837430479336e-05, "hard_edit_precision_loss": 0.5179585725069046, "selective_hard_edit_loss": 4.243980634212494, "deletion_candidate_loss": 0.03400944843888283, "deletion_length_loss": 0.9050681546330452, "deletion_positive_reward_loss": 1.0984786748886108, "run_length_loss": 0.9403936445713044, "hard_edit_entropy_excess_mean": 0.010682044783607125, "hard_edit_agreement_deficit_mean": 0.010876228543929755, "support_loss": 0.18357814364135266, "preserve_loss": 0.07103519728407263, "uncertainty_loss": 0.03453579400666058, "predicted_length": 2053.817059326172, "target_length": 2028.3, "predicted_insertions": 108.10751914978027, "target_insertions": 6.65, "trust_gate_mean": 0.9181739509105682, "support_confidence_mean": 0.9247685849666596, "support_uncertainty_mean": 0.04544495684094727, "selective_hard_edit_fraction": 0.01590306907892227}
# train step=380: {"loss": 3.558324803411961, "edit_loss": 1.4923325791954993, "sequence_loss": 0.16847868915647268, "length_loss": 0.01798039982750197, "insertion_count_loss": 0.044254149217158555, "trust_loss": 0.2938874576240778, "hard_edit_loss": 3.810300296294145e-05, "hard_edit_precision_loss": 0.5110569756478072, "selective_hard_edit_loss": 4.255085575580597, "deletion_candidate_loss": 0.03475680663250387, "deletion_length_loss": 0.8886621817946434, "deletion_positive_reward_loss": 1.1413331568241118, "run_length_loss": 0.9750693619251252, "hard_edit_entropy_excess_mean": 0.009976147953420878, "hard_edit_agreement_deficit_mean": 0.010238536051474512, "support_loss": 0.17311852052807808, "preserve_loss": 0.05019104527309537, "uncertainty_loss": 0.03434215364977718, "predicted_length": 2012.1224365234375, "target_length": 1980.0, "predicted_insertions": 95.08286972045899, "target_insertions": 6.7, "trust_gate_mean": 0.9234831780195236, "support_confidence_mean": 0.9121933609247208, "support_uncertainty_mean": 0.050943430652841924, "selective_hard_edit_fraction": 0.018418959621340037}
# train step=400: {"loss": 5.707516229152679, "edit_loss": 2.876551477611065, "sequence_loss": 0.3136301640421152, "length_loss": 0.06798109356574286, "insertion_count_loss": 0.0674554541707039, "trust_loss": 0.21803336925804614, "hard_edit_loss": 3.2705876628824625e-05, "hard_edit_precision_loss": 1.04013042896986, "selective_hard_edit_loss": 3.920391047000885, "deletion_candidate_loss": 0.0662266205996275, "deletion_length_loss": 1.224332231283188, "deletion_positive_reward_loss": 1.2125334441661835, "run_length_loss": 1.0535337895154953, "hard_edit_entropy_excess_mean": 0.01091639674268663, "hard_edit_agreement_deficit_mean": 0.014440185041166842, "support_loss": 0.24309684634208678, "preserve_loss": 0.1151728336699307, "uncertainty_loss": 0.045847192080691455, "predicted_length": 1973.5081787109375, "target_length": 1874.8, "predicted_insertions": 128.68947658538818, "target_insertions": 6.95, "trust_gate_mean": 0.9047926843166352, "support_confidence_mean": 0.942885085940361, "support_uncertainty_mean": 0.03634577081538737, "selective_hard_edit_fraction": 0.05693421615287662}
# train step=420: {"loss": 5.148808461427689, "edit_loss": 2.474681521067396, "sequence_loss": 0.3174980204552412, "length_loss": 0.09038833629456348, "insertion_count_loss": 0.07384003531187773, "trust_loss": 0.288306238502264, "hard_edit_loss": 6.128118507846559e-05, "hard_edit_precision_loss": 0.9708946287631989, "selective_hard_edit_loss": 3.739925265312195, "deletion_candidate_loss": 0.053285777755081656, "deletion_length_loss": 1.109112338721752, "deletion_positive_reward_loss": 1.1725257158279419, "run_length_loss": 0.9522436767816543, "hard_edit_entropy_excess_mean": 0.012033501709811389, "hard_edit_agreement_deficit_mean": 0.015696154616307467, "support_loss": 0.24837324097752572, "preserve_loss": 0.0658888948149979, "uncertainty_loss": 0.04155976348556578, "predicted_length": 2026.04765625, "target_length": 1889.3, "predicted_insertions": 134.54002571105957, "target_insertions": 3.4, "trust_gate_mean": 0.9126615971326828, "support_confidence_mean": 0.9135358095169067, "support_uncertainty_mean": 0.051742664549965414, "selective_hard_edit_fraction": 0.06812942828983068}
# train step=440: {"loss": 4.462874652445317, "edit_loss": 2.1769333506934343, "sequence_loss": 0.2311854377388954, "length_loss": 0.022757670550709007, "insertion_count_loss": 0.052123022731393576, "trust_loss": 0.2811616431921721, "hard_edit_loss": 6.253077256133111e-05, "hard_edit_precision_loss": 0.7920170463621616, "selective_hard_edit_loss": 3.5288262963294983, "deletion_candidate_loss": 0.04797998801805079, "deletion_length_loss": 0.9081775963306427, "deletion_positive_reward_loss": 1.0150709211826325, "run_length_loss": 0.9909119844436646, "hard_edit_entropy_excess_mean": 0.011056896962691099, "hard_edit_agreement_deficit_mean": 0.014039791165851056, "support_loss": 0.22182922046631576, "preserve_loss": 0.06338819554075599, "uncertainty_loss": 0.03906285259872675, "predicted_length": 1970.8775329589844, "target_length": 1951.55, "predicted_insertions": 116.6627103805542, "target_insertions": 14.65, "trust_gate_mean": 0.9144579261541367, "support_confidence_mean": 0.9175052493810654, "support_uncertainty_mean": 0.048928129696287216, "selective_hard_edit_fraction": 0.032450098160188644}
# train step=460: {"loss": 3.8223569810390474, "edit_loss": 1.5520275451242924, "sequence_loss": 0.1978179182857275, "length_loss": 0.04569312195526436, "insertion_count_loss": 0.05554719865322113, "trust_loss": 0.2537122625857592, "hard_edit_loss": 2.0870570206454887e-05, "hard_edit_precision_loss": 0.6106081388890743, "selective_hard_edit_loss": 4.4450178980827335, "deletion_candidate_loss": 0.045662181731313464, "deletion_length_loss": 1.0107534527778625, "deletion_positive_reward_loss": 1.0990407943725586, "run_length_loss": 0.9680803745985032, "hard_edit_entropy_excess_mean": 0.012360518099740148, "hard_edit_agreement_deficit_mean": 0.012893050559796393, "support_loss": 0.20022839531302453, "preserve_loss": 0.06943564610555768, "uncertainty_loss": 0.0352112605702132, "predicted_length": 2056.6743347167967, "target_length": 1974.65, "predicted_insertions": 111.96751480102539, "target_insertions": 3.05, "trust_gate_mean": 0.9154641717672348, "support_confidence_mean": 0.924937391281128, "support_uncertainty_mean": 0.04636645814171061, "selective_hard_edit_fraction": 0.036767578125}
# train step=480: {"loss": 4.742541766166687, "edit_loss": 2.211344151198864, "sequence_loss": 0.22458233386278154, "length_loss": 0.031747637933585794, "insertion_count_loss": 0.058148328214883804, "trust_loss": 0.32084187492728233, "hard_edit_loss": 2.8605741698584096e-05, "hard_edit_precision_loss": 0.7729786440730095, "selective_hard_edit_loss": 4.5537140488624575, "deletion_candidate_loss": 0.050551688950508836, "deletion_length_loss": 0.9996540904045105, "deletion_positive_reward_loss": 1.217495745420456, "run_length_loss": 0.9765700101852417, "hard_edit_entropy_excess_mean": 0.010319726029410958, "hard_edit_agreement_deficit_mean": 0.013185293576680124, "support_loss": 0.22018037252128125, "preserve_loss": 0.1089410780929029, "uncertainty_loss": 0.05115745635703206, "predicted_length": 2041.106884765625, "target_length": 1991.9, "predicted_insertions": 121.48373794555664, "target_insertions": 7.5, "trust_gate_mean": 0.907759627699852, "support_confidence_mean": 0.8968948572874069, "support_uncertainty_mean": 0.05848426623269916, "selective_hard_edit_fraction": 0.0328369140625}
# train step=500: {"loss": 3.5348666489124296, "edit_loss": 1.426287405192852, "sequence_loss": 0.1607273044064641, "length_loss": 0.015171555870620069, "insertion_count_loss": 0.04110705358907581, "trust_loss": 0.2290143918246031, "hard_edit_loss": 1.5430853415665525e-05, "hard_edit_precision_loss": 0.5632831491529942, "selective_hard_edit_loss": 4.204132854938507, "deletion_candidate_loss": 0.031852865032851695, "deletion_length_loss": 0.9280590996146202, "deletion_positive_reward_loss": 1.109502875804901, "run_length_loss": 0.9255054801702499, "hard_edit_entropy_excess_mean": 0.00954035718459636, "hard_edit_agreement_deficit_mean": 0.011880915099754929, "support_loss": 0.16713639199733735, "preserve_loss": 0.07272957302629948, "uncertainty_loss": 0.03892326080240309, "predicted_length": 2049.1429931640623, "target_length": 2025.05, "predicted_insertions": 90.07142887115478, "target_insertions": 6.3, "trust_gate_mean": 0.9145365744829178, "support_confidence_mean": 0.9400100380182266, "support_uncertainty_mean": 0.036778592760674654, "selective_hard_edit_fraction": 0.0200927734375}
# train step=520: {"loss": 3.3679382741451263, "edit_loss": 1.1974073518067598, "sequence_loss": 0.14431287609040738, "length_loss": 0.011041239686892367, "insertion_count_loss": 0.03898566598072648, "trust_loss": 0.33916146755218507, "hard_edit_loss": 4.8548874541154416e-05, "hard_edit_precision_loss": 0.5675853624939918, "selective_hard_edit_loss": 4.415007770061493, "deletion_candidate_loss": 0.03415735173039138, "deletion_length_loss": 0.8839413538575173, "deletion_positive_reward_loss": 1.2074883460998536, "run_length_loss": 0.9661990135908127, "hard_edit_entropy_excess_mean": 0.010984873148845508, "hard_edit_agreement_deficit_mean": 0.01259696736233309, "support_loss": 0.18707143776118756, "preserve_loss": 0.0839474868029356, "uncertainty_loss": 0.04236669046804309, "predicted_length": 2033.5502502441407, "target_length": 2018.15, "predicted_insertions": 87.59337463378907, "target_insertions": 8.4, "trust_gate_mean": 0.9314681679010391, "support_confidence_mean": 0.8965283513069153, "support_uncertainty_mean": 0.059007971361279485, "selective_hard_edit_fraction": 0.012459967005997896}
# train step=540: {"loss": 3.3686886459589003, "edit_loss": 1.372751570492983, "sequence_loss": 0.16878017373383045, "length_loss": 0.031931941164657474, "insertion_count_loss": 0.04056900339201093, "trust_loss": 0.2959593996405602, "hard_edit_loss": 1.54686480449584e-05, "hard_edit_precision_loss": 0.5558614034205676, "selective_hard_edit_loss": 3.501614511013031, "deletion_candidate_loss": 0.040383672993630174, "deletion_length_loss": 0.9522011384367943, "deletion_positive_reward_loss": 1.192338028550148, "run_length_loss": 0.9222508341073989, "hard_edit_entropy_excess_mean": 0.01135488653089851, "hard_edit_agreement_deficit_mean": 0.012264753447379918, "support_loss": 0.17489640694111586, "preserve_loss": 0.06396174412220716, "uncertainty_loss": 0.064313994650729, "predicted_length": 2058.3150390625, "target_length": 1998.8, "predicted_insertions": 85.78582439422607, "target_insertions": 4.5, "trust_gate_mean": 0.9285110354423523, "support_confidence_mean": 0.9105969548225403, "support_uncertainty_mean": 0.05245791971683502, "selective_hard_edit_fraction": 0.026708984375}
# train step=560: {"loss": 4.282296919822693, "edit_loss": 1.8609574360772967, "sequence_loss": 0.20051706172525882, "length_loss": 0.03957251886040467, "insertion_count_loss": 0.05032239463180303, "trust_loss": 0.2843859948217869, "hard_edit_loss": 4.3074607557969105e-05, "hard_edit_precision_loss": 0.7803128264844418, "selective_hard_edit_loss": 3.9826460123062133, "deletion_candidate_loss": 0.04292155294679105, "deletion_length_loss": 1.1149103984236717, "deletion_positive_reward_loss": 1.2421873450279235, "run_length_loss": 0.9093742549419404, "hard_edit_entropy_excess_mean": 0.009870449942536653, "hard_edit_agreement_deficit_mean": 0.011112543777562678, "support_loss": 0.18654996454715728, "preserve_loss": 0.08256316995248199, "uncertainty_loss": 0.03851149664260447, "predicted_length": 1972.9880798339843, "target_length": 1912.1, "predicted_insertions": 96.3029125213623, "target_insertions": 3.4, "trust_gate_mean": 0.906402200460434, "support_confidence_mean": 0.9169429272413254, "support_uncertainty_mean": 0.04853549676481635, "selective_hard_edit_fraction": 0.03420733036473393}
# train step=580: {"loss": 4.770503801107407, "edit_loss": 2.116746165161021, "sequence_loss": 0.21242756098508836, "length_loss": 0.030992526760518134, "insertion_count_loss": 0.04675362184643746, "trust_loss": 0.35268308557569983, "hard_edit_loss": 2.7164251810063435e-05, "hard_edit_precision_loss": 0.9212500087916851, "selective_hard_edit_loss": 4.586667311191559, "deletion_candidate_loss": 0.05072280908934772, "deletion_length_loss": 0.9047514751553536, "deletion_positive_reward_loss": 1.0889009803533554, "run_length_loss": 0.8398215770721436, "hard_edit_entropy_excess_mean": 0.010327141347806901, "hard_edit_agreement_deficit_mean": 0.014176658657379448, "support_loss": 0.21673476472496986, "preserve_loss": 0.08756475090049207, "uncertainty_loss": 0.0471028774511069, "predicted_length": 1985.1665466308593, "target_length": 1949.8, "predicted_insertions": 102.74310464859009, "target_insertions": 10.25, "trust_gate_mean": 0.9127617448568344, "support_confidence_mean": 0.8947800189256668, "support_uncertainty_mean": 0.0599489807151258, "selective_hard_edit_fraction": 0.03077193717472255}
# train step=600: {"loss": 4.0357015311717985, "edit_loss": 1.5893180057406426, "sequence_loss": 0.19459973201155661, "length_loss": 0.022178392199566587, "insertion_count_loss": 0.04547088388353586, "trust_loss": 0.2641130264848471, "hard_edit_loss": 3.719997323941016e-05, "hard_edit_precision_loss": 0.8712876901030541, "selective_hard_edit_loss": 3.8209356725215913, "deletion_candidate_loss": 0.04282388994470239, "deletion_length_loss": 0.9549412280321121, "deletion_positive_reward_loss": 1.2461195826530456, "run_length_loss": 0.821222385764122, "hard_edit_entropy_excess_mean": 0.009908026969060301, "hard_edit_agreement_deficit_mean": 0.010445230267941951, "support_loss": 0.19741905704140664, "preserve_loss": 0.08134280722588301, "uncertainty_loss": 0.03747044843621552, "predicted_length": 1989.0008728027344, "target_length": 1964.9, "predicted_insertions": 94.22430458068848, "target_insertions": 6.0, "trust_gate_mean": 0.9174084186553955, "support_confidence_mean": 0.9282397598028183, "support_uncertainty_mean": 0.04296747855842113, "selective_hard_edit_fraction": 0.022919694194570184}
# train step=620: {"loss": 4.871810203790664, "edit_loss": 2.367957580462098, "sequence_loss": 0.24143975153565406, "length_loss": 0.0497754030948272, "insertion_count_loss": 0.05128321833908558, "trust_loss": 0.35285892747342584, "hard_edit_loss": 7.060181986231484e-05, "hard_edit_precision_loss": 0.8370389863848686, "selective_hard_edit_loss": 4.1786696195602415, "deletion_candidate_loss": 0.04965276513248682, "deletion_length_loss": 1.0162047192454338, "deletion_positive_reward_loss": 1.0298237353563309, "run_length_loss": 0.8651715785264968, "hard_edit_entropy_excess_mean": 0.010690441401675344, "hard_edit_agreement_deficit_mean": 0.011646412534173579, "support_loss": 0.20203135646879672, "preserve_loss": 0.07109268885105849, "uncertainty_loss": 0.04130251291207969, "predicted_length": 2030.3453308105468, "target_length": 1953.1, "predicted_insertions": 103.53132133483886, "target_insertions": 6.4, "trust_gate_mean": 0.9302987366914749, "support_confidence_mean": 0.8905726313591004, "support_uncertainty_mean": 0.06255321265198291, "selective_hard_edit_fraction": 0.04402500372380018}
# train step=640: {"loss": 5.717475569248199, "edit_loss": 2.95533300191164, "sequence_loss": 0.33977446258068084, "length_loss": 0.08975940016680398, "insertion_count_loss": 0.05976978028193116, "trust_loss": 0.27236832268536093, "hard_edit_loss": 3.927096200868618e-05, "hard_edit_precision_loss": 1.0895864382386207, "selective_hard_edit_loss": 3.453439497947693, "deletion_candidate_loss": 0.05981126027181745, "deletion_length_loss": 1.0687133088707923, "deletion_positive_reward_loss": 1.2001347362995147, "run_length_loss": 0.8568912029266358, "hard_edit_entropy_excess_mean": 0.009548924397677183, "hard_edit_agreement_deficit_mean": 0.014651259640231729, "support_loss": 0.22538680620491505, "preserve_loss": 0.10364013924263418, "uncertainty_loss": 0.038209050940349695, "predicted_length": 1949.4917724609375, "target_length": 1826.75, "predicted_insertions": 112.6474105834961, "target_insertions": 10.15, "trust_gate_mean": 0.9265624940395355, "support_confidence_mean": 0.9219582140445709, "support_uncertainty_mean": 0.04599067640956491, "selective_hard_edit_fraction": 0.0712227288633585}
# train step=660: {"loss": 4.134000736474991, "edit_loss": 1.6996276371181012, "sequence_loss": 0.23062961008399724, "length_loss": 0.05545515471312683, "insertion_count_loss": 0.05463691167533398, "trust_loss": 0.3176233652979136, "hard_edit_loss": 5.6939429501312586e-05, "hard_edit_precision_loss": 0.8636314898729325, "selective_hard_edit_loss": 3.6369177103042603, "deletion_candidate_loss": 0.04499473366886377, "deletion_length_loss": 1.0169417798519134, "deletion_positive_reward_loss": 1.1190000236034394, "run_length_loss": 0.8471149623394012, "hard_edit_entropy_excess_mean": 0.010200177691876889, "hard_edit_agreement_deficit_mean": 0.01234190072864294, "support_loss": 0.20850550271570684, "preserve_loss": 0.08943201955407858, "uncertainty_loss": 0.04127876572310925, "predicted_length": 2046.082373046875, "target_length": 1960.65, "predicted_insertions": 106.83301677703858, "target_insertions": 4.4, "trust_gate_mean": 0.9279173940420151, "support_confidence_mean": 0.9062819391489029, "support_uncertainty_mean": 0.054023787821643056, "selective_hard_edit_fraction": 0.042724609375}
# train step=680: {"loss": 2.9534612372517586, "edit_loss": 1.1640575537458062, "sequence_loss": 0.1269316378980875, "length_loss": 0.014252757823123829, "insertion_count_loss": 0.025465986412018537, "trust_loss": 0.28927652947604654, "hard_edit_loss": 1.8389227358106554e-05, "hard_edit_precision_loss": 0.42197675704956056, "selective_hard_edit_loss": 3.813062846660614, "deletion_candidate_loss": 0.023886905796825886, "deletion_length_loss": 0.74261674284935, "deletion_positive_reward_loss": 1.068819633126259, "run_length_loss": 0.8628288894891739, "hard_edit_entropy_excess_mean": 0.0151230797637254, "hard_edit_agreement_deficit_mean": 0.013997870543971658, "support_loss": 0.19514456130564212, "preserve_loss": 0.05045891106128693, "uncertainty_loss": 0.038716547377407554, "predicted_length": 2050.7886169433596, "target_length": 2025.8, "predicted_insertions": 58.46296710968018, "target_insertions": 6.35, "trust_gate_mean": 0.9482974737882615, "support_confidence_mean": 0.9174620687961579, "support_uncertainty_mean": 0.05198534592054784, "selective_hard_edit_fraction": 0.014657951891422272}
# train step=700: {"loss": 3.923124086856842, "edit_loss": 1.745458624139428, "sequence_loss": 0.18960160501301287, "length_loss": 0.040102818404557185, "insertion_count_loss": 0.042195435240864755, "trust_loss": 0.2866696123033762, "hard_edit_loss": 8.799265082757302e-05, "hard_edit_precision_loss": 0.6465176463127136, "selective_hard_edit_loss": 3.799171286821365, "deletion_candidate_loss": 0.055344291031360626, "deletion_length_loss": 1.0230204299092294, "deletion_positive_reward_loss": 1.1505535632371902, "run_length_loss": 0.8343613803386688, "hard_edit_entropy_excess_mean": 0.01140547429677099, "hard_edit_agreement_deficit_mean": 0.013026259513571859, "support_loss": 0.18316048830747605, "preserve_loss": 0.05750733243767172, "uncertainty_loss": 0.03765818430110812, "predicted_length": 2059.2825256347655, "target_length": 1994.75, "predicted_insertions": 87.28880977630615, "target_insertions": 6.0, "trust_gate_mean": 0.9285687536001206, "support_confidence_mean": 0.9162752240896225, "support_uncertainty_mean": 0.05022382207680494, "selective_hard_edit_fraction": 0.02939453125}
# train step=720: {"loss": 4.271838688850403, "edit_loss": 1.952958364225924, "sequence_loss": 0.1905177326872945, "length_loss": 0.021484344886448525, "insertion_count_loss": 0.046996422205120326, "trust_loss": 0.35292306654155253, "hard_edit_loss": 4.7904093113970704e-05, "hard_edit_precision_loss": 0.7325193822383881, "selective_hard_edit_loss": 3.9992517054080965, "deletion_candidate_loss": 0.06599843949079513, "deletion_length_loss": 0.885731826722622, "deletion_positive_reward_loss": 1.0631895959377289, "run_length_loss": 0.8563176542520523, "hard_edit_entropy_excess_mean": 0.01066026259213686, "hard_edit_agreement_deficit_mean": 0.012655318714678288, "support_loss": 0.19809250738471745, "preserve_loss": 0.11114456760697067, "uncertainty_loss": 0.22702078213915228, "predicted_length": 2022.0893310546876, "target_length": 1980.55, "predicted_insertions": 100.68174304962159, "target_insertions": 7.6, "trust_gate_mean": 0.9223260998725891, "support_confidence_mean": 0.8881997615098953, "support_uncertainty_mean": 0.06328153079375624, "selective_hard_edit_fraction": 0.02361789820715785}
# train step=740: {"loss": 3.7966261863708497, "edit_loss": 1.7040645956993103, "sequence_loss": 0.1766603035852313, "length_loss": 0.02314465446397662, "insertion_count_loss": 0.04015542892739177, "trust_loss": 0.29633310399949553, "hard_edit_loss": 4.707301502548944e-05, "hard_edit_precision_loss": 0.6241682067513465, "selective_hard_edit_loss": 3.7214053750038145, "deletion_candidate_loss": 0.045765012037009, "deletion_length_loss": 0.8166435584425926, "deletion_positive_reward_loss": 1.1494677782058715, "run_length_loss": 0.7808421537280082, "hard_edit_entropy_excess_mean": 0.011842809873633087, "hard_edit_agreement_deficit_mean": 0.012045543687418104, "support_loss": 0.19052189514040946, "preserve_loss": 0.12117293756455183, "uncertainty_loss": 0.09943362521007656, "predicted_length": 2063.519873046875, "target_length": 2017.85, "predicted_insertions": 89.5065544128418, "target_insertions": 8.15, "trust_gate_mean": 0.9329390436410904, "support_confidence_mean": 0.9116349399089814, "support_uncertainty_mean": 0.052540570474229754, "selective_hard_edit_fraction": 0.0219970703125}
# train step=760: {"loss": 3.843079036474228, "edit_loss": 1.5694250278174877, "sequence_loss": 0.18785555213689803, "length_loss": 0.042222905158996585, "insertion_count_loss": 0.040044063422828916, "trust_loss": 0.31071922481060027, "hard_edit_loss": 3.228199250315811e-05, "hard_edit_precision_loss": 0.6393349461257458, "selective_hard_edit_loss": 4.5427940607070925, "deletion_candidate_loss": 0.04796721483580768, "deletion_length_loss": 0.9148840591311455, "deletion_positive_reward_loss": 0.9424755185842514, "run_length_loss": 0.8363105922937393, "hard_edit_entropy_excess_mean": 0.012471569562330842, "hard_edit_agreement_deficit_mean": 0.012927033542655408, "support_loss": 0.20105129815638065, "preserve_loss": 0.10631726360879838, "uncertainty_loss": 0.03772121174260974, "predicted_length": 2058.074395751953, "target_length": 1986.3, "predicted_insertions": 83.72517261505126, "target_insertions": 5.6, "trust_gate_mean": 0.9334871143102645, "support_confidence_mean": 0.9083466589450836, "support_uncertainty_mean": 0.05475695850327611, "selective_hard_edit_fraction": 0.034033203125}
# train step=780: {"loss": 3.9887378454208373, "edit_loss": 1.7717272266745567, "sequence_loss": 0.19862451702356337, "length_loss": 0.02853125605615787, "insertion_count_loss": 0.03910230593755841, "trust_loss": 0.2671937108039856, "hard_edit_loss": 6.724810515095214e-05, "hard_edit_precision_loss": 0.7558839075267315, "selective_hard_edit_loss": 3.6300652861595153, "deletion_candidate_loss": 0.04726117961108685, "deletion_length_loss": 0.7661672219634056, "deletion_positive_reward_loss": 1.1346922248601914, "run_length_loss": 0.8132664024829864, "hard_edit_entropy_excess_mean": 0.01348955298308283, "hard_edit_agreement_deficit_mean": 0.014284784905612469, "support_loss": 0.2125988218933344, "preserve_loss": 0.0696101472247392, "uncertainty_loss": 0.03901160629466176, "predicted_length": 2040.359600830078, "target_length": 1990.9, "predicted_insertions": 86.1753303527832, "target_insertions": 8.85, "trust_gate_mean": 0.9347975134849549, "support_confidence_mean": 0.923303160071373, "support_uncertainty_mean": 0.04795815523248166, "selective_hard_edit_fraction": 0.03143032155930996}
# train step=800: {"loss": 3.8802198827266694, "edit_loss": 1.795525478385389, "sequence_loss": 0.17925653290003538, "length_loss": 0.01522650762926787, "insertion_count_loss": 0.03256841041147709, "trust_loss": 0.34757679924368856, "hard_edit_loss": 6.186844990736517e-05, "hard_edit_precision_loss": 0.5744052186608315, "selective_hard_edit_loss": 3.9750851333141326, "deletion_candidate_loss": 0.040115043288096786, "deletion_length_loss": 0.9323370099067688, "deletion_positive_reward_loss": 1.159493437409401, "run_length_loss": 0.745343542098999, "hard_edit_entropy_excess_mean": 0.01016768196132034, "hard_edit_agreement_deficit_mean": 0.011222058488056064, "support_loss": 0.17087087631225586, "preserve_loss": 0.05039608785882592, "uncertainty_loss": 0.03841587454080582, "predicted_length": 2028.5149536132812, "target_length": 1999.35, "predicted_insertions": 73.91252689361572, "target_insertions": 8.75, "trust_gate_mean": 0.9391234278678894, "support_confidence_mean": 0.8965631484985351, "support_uncertainty_mean": 0.05895860167220235, "selective_hard_edit_fraction": 0.024395310878753663}
# train step=820: {"loss": 4.189638024568557, "edit_loss": 1.9948848098516465, "sequence_loss": 0.21802997794002293, "length_loss": 0.046886272088158876, "insertion_count_loss": 0.037874228321015835, "trust_loss": 0.2590764548629522, "hard_edit_loss": 5.28501489277744e-05, "hard_edit_precision_loss": 0.6594093553721905, "selective_hard_edit_loss": 3.950056827068329, "deletion_candidate_loss": 0.05199217828921974, "deletion_length_loss": 0.9467468142509461, "deletion_positive_reward_loss": 1.0269772469997407, "run_length_loss": 0.7415941476821899, "hard_edit_entropy_excess_mean": 0.011828828020952642, "hard_edit_agreement_deficit_mean": 0.013643521186895668, "support_loss": 0.18864823803305625, "preserve_loss": 0.0750009675975889, "uncertainty_loss": 0.03508193683810532, "predicted_length": 2058.875109863281, "target_length": 1981.1, "predicted_insertions": 80.98117733001709, "target_insertions": 8.25, "trust_gate_mean": 0.9407498896121979, "support_confidence_mean": 0.9261744499206543, "support_uncertainty_mean": 0.04528054618276656, "selective_hard_edit_fraction": 0.03857155083678663}
# ...
# train step=1440: {"loss": 2.5027880534529685, "edit_loss": 1.1333637297153474, "sequence_loss": 0.13985413229092955, "length_loss": 0.03648983339953702, "insertion_count_loss": 0.02601476018317044, "trust_loss": 0.2387927059084177, "hard_edit_loss": 0.0005399465950176819, "hard_edit_precision_loss": 0.2976674009114504, "selective_hard_edit_loss": 2.841730776429176, "deletion_candidate_loss": 0.05344268882181495, "deletion_length_loss": 0.8291238516569137, "deletion_positive_reward_loss": 0.8027572013437748, "run_length_loss": 0.12972716074436902, "hard_edit_entropy_excess_mean": 0.012445741333067417, "hard_edit_agreement_deficit_mean": 0.012306276382878423, "support_loss": 0.0923006335273385, "preserve_loss": 0.05950014791451395, "uncertainty_loss": 0.011629421974066644, "predicted_length": 2075.9503784179688, "target_length": 2008.1, "predicted_insertions": 55.9648980140686, "target_insertions": 5.15, "trust_gate_mean": 0.9423373520374299, "support_confidence_mean": 0.9331612318754197, "support_uncertainty_mean": 0.04363687108270824, "selective_hard_edit_fraction": 0.0240966796875}
# train step=1460: {"loss": 2.0536416560411452, "edit_loss": 0.8068570360541344, "sequence_loss": 0.11953486073762179, "length_loss": 0.033358818292617796, "insertion_count_loss": 0.03288005138747394, "trust_loss": 0.25224863141775133, "hard_edit_loss": 0.0006072836418752559, "hard_edit_precision_loss": 0.34087177366018295, "selective_hard_edit_loss": 2.195494790375233, "deletion_candidate_loss": 0.0620802472345531, "deletion_length_loss": 0.6761045696213841, "deletion_positive_reward_loss": 0.7154098615050316, "run_length_loss": 0.1013954718131572, "hard_edit_entropy_excess_mean": 0.01195939953904599, "hard_edit_agreement_deficit_mean": 0.012174323899671435, "support_loss": 0.09033067356795073, "preserve_loss": 0.08925847662612796, "uncertainty_loss": 0.014041912939865142, "predicted_length": 2085.6167846679687, "target_length": 2019.65, "predicted_insertions": 72.8057029724121, "target_insertions": 6.4, "trust_gate_mean": 0.9450489938259125, "support_confidence_mean": 0.9283195257186889, "support_uncertainty_mean": 0.045899913925677535, "selective_hard_edit_fraction": 0.0173828125}
# train step=1480: {"loss": 2.8236867636442184, "edit_loss": 1.2728605886921287, "sequence_loss": 0.18190848687663674, "length_loss": 0.057493595755659044, "insertion_count_loss": 0.03360240082256496, "trust_loss": 0.29040996395051477, "hard_edit_loss": 0.0005517504290764918, "hard_edit_precision_loss": 0.34064919762313367, "selective_hard_edit_loss": 3.3777250424027443, "deletion_candidate_loss": 0.05867987831588835, "deletion_length_loss": 0.6926481705158949, "deletion_positive_reward_loss": 0.9290839821100235, "run_length_loss": 0.09616245245561003, "hard_edit_entropy_excess_mean": 0.014106302498839795, "hard_edit_agreement_deficit_mean": 0.012777943932451307, "support_loss": 0.09624162670224905, "preserve_loss": 0.04964275623206049, "uncertainty_loss": 0.013534996681846679, "predicted_length": 2049.947717285156, "target_length": 1949.3, "predicted_insertions": 67.11688766479492, "target_insertions": 3.85, "trust_gate_mean": 0.9444390892982483, "support_confidence_mean": 0.9162189781665802, "support_uncertainty_mean": 0.053527765441685915, "selective_hard_edit_fraction": 0.030576633336022497}
# train step=1500: {"loss": 1.9840772792696952, "edit_loss": 0.7021632924675941, "sequence_loss": 0.10105939228087664, "length_loss": 0.02399026621133089, "insertion_count_loss": 0.02684268308803439, "trust_loss": 0.2840059671550989, "hard_edit_loss": 0.0005534396766961435, "hard_edit_precision_loss": 0.3139335080981255, "selective_hard_edit_loss": 2.7368723645806314, "deletion_candidate_loss": 0.04643167583271861, "deletion_length_loss": 0.5508555442094802, "deletion_positive_reward_loss": 0.7722481034696103, "run_length_loss": 0.08876399109140039, "hard_edit_entropy_excess_mean": 0.011844254622701555, "hard_edit_agreement_deficit_mean": 0.011308952688705177, "support_loss": 0.07335256375372409, "preserve_loss": 0.056889822240918875, "uncertainty_loss": 0.012112768564838916, "predicted_length": 2045.8648498535156, "target_length": 1998.05, "predicted_insertions": 58.59449787139893, "target_insertions": 4.35, "trust_gate_mean": 0.9410266876220703, "support_confidence_mean": 0.9178662359714508, "support_uncertainty_mean": 0.05088874583598226, "selective_hard_edit_fraction": 0.011867453856393696}
# {
#   "train_loss": 2.786999676719308,
#   "train_edit_loss": 1.275433548853888,
#   "train_sequence_loss": 0.1646626810481151,
#   "train_length_loss": 0.04708998929825611,
#   "train_insertion_count_loss": 0.038143407044000925,
#   "train_trust_loss": 0.2830972123220563,
#   "train_hard_edit_loss": 0.0007498290506282501,
#   "train_hard_edit_precision_loss": 0.4170779380823175,
#   "train_selective_hard_edit_loss": 2.7849504369099933,
#   "train_deletion_candidate_loss": 0.06534244434861466,
#   "train_deletion_length_loss": 0.7048509472298126,
#   "train_deletion_positive_reward_loss": 0.833603408853213,
#   "train_run_length_loss": 0.1445618279185146,
#   "train_hard_edit_entropy_excess_mean": 0.011754893519023124,
#   "train_hard_edit_agreement_deficit_mean": 0.012589323591130476,
#   "train_support_loss": 0.09317170996405184,
#   "train_preserve_loss": 0.06601953392724196,
#   "train_uncertainty_loss": 0.01503060516078646,
#   "train_predicted_length": 2068.1058225911456,
#   "train_target_length": 1985.198,
#   "train_predicted_insertions": 78.9649056189855,
#   "train_target_insertions": 6.733333333333333,
#   "train_trust_gate_mean": 0.9372686851819356,
#   "train_support_confidence_mean": 0.9175931303501129,
#   "train_support_uncertainty_mean": 0.050903565681849915,
#   "train_selective_hard_edit_fraction": 0.02651993302310196,
#   "val_loss": 2.7825137533893187,
#   "val_edit_loss": 1.2954372511528587,
#   "val_sequence_loss": 0.1789048907098671,
#   "val_length_loss": 0.05767222359078005,
#   "val_insertion_count_loss": 0.03511732397476832,
#   "val_trust_loss": 0.2908009015818437,
#   "val_hard_edit_loss": 0.0005911492738014961,
#   "val_hard_edit_precision_loss": 0.36216272960354884,
#   "val_selective_hard_edit_loss": 2.9868851568847896,
#   "val_deletion_candidate_loss": 0.06917466903912524,
#   "val_deletion_length_loss": 0.6496424670976897,
#   "val_deletion_positive_reward_loss": 0.8794355631570021,
#   "val_run_length_loss": 0.0812093127593398,
#   "val_hard_edit_entropy_excess_mean": 0.011264855841892615,
#   "val_hard_edit_agreement_deficit_mean": 0.011720743347657844,
#   "val_support_loss": 0.07831217084048937,
#   "val_preserve_loss": 0.06139906786615029,
#   "val_uncertainty_loss": 0.020364750342560002,
#   "val_predicted_length": 2063.144659342448,
#   "val_target_length": 1964.3106666666667,
#   "val_predicted_insertions": 69.08087958272299,
#   "val_target_insertions": 4.51,
#   "val_trust_gate_mean": 0.9367267681360245,
#   "val_support_confidence_mean": 0.9138668655554454,
#   "val_support_uncertainty_mean": 0.05232186601373057,
#   "val_selective_hard_edit_fraction": 0.03360248230560683,
#   "val_edit_accuracy": 0.9571267879803975,
#   "val_core_edit_accuracy": 0.9592849314212799,
#   "val_hard_edit_false_positive_rate": 2.806959149893373e-05,
#   "val_copy_recall": 0.999971109787623,
#   "val_copy_precision": 0.959425316631794,
#   "val_copy_f1": 0.9780247974172195,
#   "val_delete_recall": 0.0,
#   "val_delete_precision": 0.0,
#   "val_delete_f1": 0.0,
#   "val_sub_recall": 0.10559647908744713,
#   "val_sub_precision": 0.42110896108547846,
#   "val_sub_f1": 0.1490285479884803,
#   "val_ins_recall": 0.0,
#   "val_ins_precision": 0.0,
#   "val_ins_f1": 0.0,
#   "val_sequence_edit_distance": 86.318,
#   "val_sequence_normalized_edit_distance": 0.04252887662165744,
#   "val_sequence_identity": 0.9574711233783422,
#   "val_predicted_length_ratio": 1.039531233837304,
#   "val_predicted_insertions_per_window": 0.0,
#   "val_target_insertions_per_window": 4.51,
#   "val_predicted_insertion_burst_length": 0.0,
#   "val_target_insertion_burst_length": 0.7816489341110895,
#   "val_homopolymer_core_error_rate": 0.05452899129331733,
#   "val_non_homopolymer_core_error_rate": 0.039734131615802956,
#   "val_low_complexity_sequence_identity": 0.0,
#   "val_repeat_rich_sequence_identity": 0.9574711233783422,
#   "val_variant_rich_sequence_identity": 0.8131154057534957,
#   "val_phased_variant_sequence_identity": 0.0,
#   "val_low_support_entropy_sequence_identity": 0.9574711233783422,
#   "val_high_support_entropy_sequence_identity": 0.0,
#   "val_low_support_agreement_sequence_identity": 0.0,
#   "val_high_support_agreement_sequence_identity": 0.9574711233783422,
#   "val_support_entropy_window_mean": 0.018510595375225723,
#   "val_support_agreement_window_mean": 0.986388013402621,
#   "val_trust_gate_window_mean": 0.9367267686128616,
#   "val_low_support_entropy_window_count": 1.0,
#   "val_high_support_entropy_window_count": 0.0,
#   "val_low_support_agreement_window_count": 0.0,
#   "val_high_support_agreement_window_count": 1.0,
#   "val_variant_site_core_error_rate": 0.5517055507289866,
#   "val_phased_variant_core_error_rate": 0.0,
#   "val_homopolymer_sequence_identity": 0.9574711233783422,
#   "val_tandem_repeat_sequence_identity": 0.9574711233783422,
#   "val_tandem_repeat_core_error_rate": 0.042424541858335336,
#   "val_variant_rich_core_error_rate": 0.5517055507289866,
#   "val_trust_gate_low_entropy_mean": 0.937980531891187,
#   "val_trust_gate_high_entropy_mean": 0.004651840925216675,
#   "val_trust_gate_low_agreement_mean": 0.6739270052512487,
#   "val_trust_gate_high_agreement_mean": 0.93967442770799,
#   "val_trust_gate_homopolymer_mean": 0.9377099335193634,
#   "val_trust_gate_non_homopolymer_mean": 0.9367753544648488,
#   "val_support_hap_agreement_mean": 0.6302326588630677,
#   "val_support_hap_consistency_mean": 0.4742157191733519,
#   "val_sub_pred_count_low_entropy": 1.3446666666666667,
#   "val_sub_pred_count_high_entropy": 0.0,
#   "val_sub_pred_count_low_agreement": 0.0,
#   "val_sub_pred_count_high_agreement": 1.3446666666666667,
#   "val_delete_pred_count_low_entropy": 0.0,
#   "val_delete_pred_count_high_entropy": 0.0,
#   "val_delete_pred_count_low_agreement": 0.0,
#   "val_delete_pred_count_high_agreement": 0.0,
#   "val_sub_precision_low_entropy": 0.42110896108547846,
#   "val_sub_recall_low_entropy": 0.1253712971645097,
#   "val_sub_f1_low_entropy": 0.16948955782749628,
#   "val_delete_precision_low_entropy": 0.0,
#   "val_delete_recall_low_entropy": 0.0,
#   "val_delete_f1_low_entropy": 0.0,
#   "val_ins_precision_low_entropy": 0.0,
#   "val_ins_recall_low_entropy": 0.0,
#   "val_ins_f1_low_entropy": 0.0,
#   "val_sub_precision_high_entropy": 0.0,
#   "val_sub_recall_high_entropy": 0.0,
#   "val_sub_f1_high_entropy": 0.0,
#   "val_delete_precision_high_entropy": 0.0,
#   "val_delete_recall_high_entropy": 0.0,
#   "val_delete_f1_high_entropy": 0.0,
#   "val_ins_precision_high_entropy": 0.0,
#   "val_ins_recall_high_entropy": 0.0,
#   "val_ins_f1_high_entropy": 0.0,
#   "val_sub_precision_low_agreement": 0.0,
#   "val_sub_recall_low_agreement": 0.0,
#   "val_sub_f1_low_agreement": 0.0,
#   "val_delete_precision_low_agreement": 0.0,
#   "val_delete_recall_low_agreement": 0.0,
#   "val_delete_f1_low_agreement": 0.0,
#   "val_ins_precision_low_agreement": 0.0,
#   "val_ins_recall_low_agreement": 0.0,
#   "val_ins_f1_low_agreement": 0.0,
#   "val_sub_precision_high_agreement": 0.42110896108547846,
#   "val_sub_recall_high_agreement": 0.13264852696533005,
#   "val_sub_f1_high_agreement": 0.1774569233748452,
#   "val_delete_precision_high_agreement": 0.0,
#   "val_delete_recall_high_agreement": 0.0,
#   "val_delete_f1_high_agreement": 0.0,
#   "val_ins_precision_high_agreement": 0.0,
#   "val_ins_recall_high_agreement": 0.0,
#   "val_ins_f1_high_agreement": 0.0,
#   "val_sub_precision_homopolymer": 0.054555555562178296,
#   "val_sub_recall_homopolymer": 0.03318661994238695,
#   "val_sub_f1_homopolymer": 0.037733439356565875,
#   "val_delete_precision_homopolymer": 0.0,
#   "val_delete_recall_homopolymer": 0.0,
#   "val_delete_f1_homopolymer": 0.0,
#   "val_ins_precision_homopolymer": 0.0,
#   "val_ins_recall_homopolymer": 0.0,
#   "val_ins_f1_homopolymer": 0.0,
#   "val_sub_precision_non_homopolymer": 0.4210346224506696,
#   "val_sub_recall_non_homopolymer": 0.10724475915481647,
#   "val_sub_f1_non_homopolymer": 0.15098026408582343,
#   "val_delete_precision_non_homopolymer": 0.0,
#   "val_delete_recall_non_homopolymer": 0.0,
#   "val_delete_f1_non_homopolymer": 0.0,
#   "val_ins_precision_non_homopolymer": 0.0,
#   "val_ins_recall_non_homopolymer": 0.0,
#   "val_ins_f1_non_homopolymer": 0.0,
#   "val_sub_precision_tandem_repeat": 0.338197034796079,
#   "val_sub_recall_tandem_repeat": 0.10968416213678817,
#   "val_sub_f1_tandem_repeat": 0.14547742008560138,
#   "val_delete_precision_tandem_repeat": 0.0,
#   "val_delete_recall_tandem_repeat": 0.0,
#   "val_delete_f1_tandem_repeat": 0.0,
#   "val_ins_precision_tandem_repeat": 0.0,
#   "val_ins_recall_tandem_repeat": 0.0,
#   "val_ins_f1_tandem_repeat": 0.0,
#   "val_sub_precision_variant_rich": 0.0013333333333333333,
#   "val_sub_recall_variant_rich": 0.0013333333333333333,
#   "val_sub_f1_variant_rich": 0.0013333333333333333,
#   "val_delete_precision_variant_rich": 0.0,
#   "val_delete_recall_variant_rich": 0.0,
#   "val_delete_f1_variant_rich": 0.0,
#   "val_ins_precision_variant_rich": 0.0,
#   "val_ins_recall_variant_rich": 0.0,
#   "val_ins_f1_variant_rich": 0.0,
#   "val_overcorrection_rate": 0.0004772727290789286,
#   "epoch": 3,
#   "val_selection_score": 0.9569938506492632
# }
# early stopping at epoch 3 after 2 stale epochs
#
# === train chr20_small / full ===
# /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/train.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/20x_chr20_small_full.yaml
# python(300) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# /Users/shanejayasundera/LRS-Error-Correction/scripts/train.py:249: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler(enabled=cfg.train.mixed_precision and device.type == "cuda")
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[17], line 40
#      38     for row in train_plans:
#      39         print(f'\n=== train {row["stage"]} / {row["run"]} ===')
# ---> 40         run_cmd(row['cmd'], env=env)
#      42 if RUN_TEST:
#      43     for row in eval_plans:
#
# Cell In[14], line 105, in run_cmd(cmd, cwd, env, dry_run)
#     103 if dry_run:
#     104     return None
# --> 105 return subprocess.run(cmd, cwd=cwd, env=env, check=True)
#
# File ~/anaconda3/envs/lrs_err_correct_env/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     524     retcode = process.poll()
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python', 'scripts/train.py', '--config', '/Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/20x_chr20_small_full.yaml']' died with <Signals.SIGKILL: 9>.

# %%
def load_json(path):
    path = Path(path)
    if not path.exists():
        return None
    return json.loads(path.read_text())


def usable_score(summary):
    identity = float(summary.get('sequence_identity', 0.0))
    overcorrection = float(summary.get('overcorrection_rate', 0.0))
    return identity - selection_weights.get('overcorrection', 0.0) * overcorrection


correction_rows = []
for row in eval_plans:
    summary = load_json(row['summary_path'])
    if summary is None:
        continue
    correction_rows.append({
        'kind': 'model', 'coverage': row.get('coverage', ''), 'train_dataset': row.get('train_dataset', row['dataset']), 'dataset': row['dataset'], 'name': row['run'],
        'sequence_identity': float(summary.get('sequence_identity', 0.0)),
        'normalized_edit_distance': float(summary.get('sequence_normalized_edit_distance', 0.0)),
        'overcorrection_rate': float(summary.get('overcorrection_rate', 0.0)),
        'hard_edit_false_positive_rate': float(summary.get('hard_edit_false_positive_rate', 0.0)),
        'repeat_sequence_identity': float(summary.get('repeat_sequence_identity', summary.get('repeat_rich_sequence_identity', 0.0))),
        'segmental_duplication_sequence_identity': float(summary.get('segmental_duplication_sequence_identity', 0.0)),
        'variant_rich_sequence_identity': float(summary.get('variant_rich_sequence_identity', 0.0)),
        'homopolymer_core_error_rate': float(summary.get('homopolymer_core_error_rate', 0.0)),
        'phased_variant_core_error_rate': float(summary.get('phased_variant_core_error_rate', 0.0)),
        'usable_correction_score': usable_score(summary),
        'summary_path': row['summary_path'],
    })
for row in baseline_plans:
    summary = load_json(row['summary_path'])
    if summary is None:
        continue
    correction_rows.append({
        'kind': f'baseline:{row["baseline"]}', 'coverage': row.get('coverage', ''), 'train_dataset': row.get('train_dataset', row['dataset']), 'dataset': row['dataset'], 'name': row['baseline'],
        'sequence_identity': float(summary.get('sequence_identity', 0.0)),
        'normalized_edit_distance': float(summary.get('sequence_normalized_edit_distance', 0.0)),
        'overcorrection_rate': float(summary.get('overcorrection_rate', 0.0)),
        'hard_edit_false_positive_rate': float(summary.get('hard_edit_false_positive_rate', 0.0)),
        'repeat_sequence_identity': float(summary.get('repeat_sequence_identity', summary.get('repeat_rich_sequence_identity', 0.0))),
        'segmental_duplication_sequence_identity': float(summary.get('segmental_duplication_sequence_identity', 0.0)),
        'variant_rich_sequence_identity': float(summary.get('variant_rich_sequence_identity', 0.0)),
        'homopolymer_core_error_rate': float(summary.get('homopolymer_core_error_rate', 0.0)),
        'phased_variant_core_error_rate': float(summary.get('phased_variant_core_error_rate', 0.0)),
        'usable_correction_score': usable_score(summary),
        'summary_path': row['summary_path'],
    })
correction_df = pd.DataFrame(correction_rows)
if not correction_df.empty:
    consensus_lookup = correction_df[correction_df['kind'] == 'baseline:consensus'][['coverage', 'dataset', 'sequence_identity', 'normalized_edit_distance', 'overcorrection_rate', 'usable_correction_score']].rename(columns={
        'sequence_identity': 'consensus_sequence_identity',
        'normalized_edit_distance': 'consensus_normalized_edit_distance',
        'overcorrection_rate': 'consensus_overcorrection_rate',
        'usable_correction_score': 'consensus_usable_correction_score',
    })
    correction_df = correction_df.merge(consensus_lookup, on=['coverage', 'dataset'], how='left')
    correction_df['delta_identity_vs_consensus'] = correction_df['sequence_identity'] - correction_df['consensus_sequence_identity'].fillna(0.0)
    correction_df['delta_ned_vs_consensus'] = correction_df['normalized_edit_distance'] - correction_df['consensus_normalized_edit_distance'].fillna(0.0)
    correction_df['delta_score_vs_consensus'] = correction_df['usable_correction_score'] - correction_df['consensus_usable_correction_score'].fillna(0.0)
    display(correction_df.sort_values(['coverage', 'dataset', 'usable_correction_score'], ascending=[True, True, False]).reset_index(drop=True))
else:
    print('No correction summaries found yet.')

external_df = pd.DataFrame([load_json(row['summary_path']) | {'dataset': row['dataset'], 'tool': row['tool']} for row in external_baseline_plans if load_json(row['summary_path']) is not None])
if not external_df.empty:
    display(external_df)
else:
    print('No external baseline summaries found yet.')

assembly_df = pd.DataFrame([load_json(row['summary_path']) | {'dataset': row['dataset']} for row in downstream_plans if row['kind'] == 'assembly' and load_json(row['summary_path']) is not None])
if not assembly_df.empty:
    display(assembly_df)
else:
    print('No assembly summaries found yet.')

variant_df = pd.DataFrame([load_json(row['summary_path']) | {'dataset': row['dataset']} for row in downstream_plans if row['kind'] == 'variant_eval' and load_json(row['summary_path']) is not None])
if not variant_df.empty:
    display(variant_df)
else:
    print('No variant-calling summaries found yet.')

combined_summary = {
    'correction': correction_rows,
    'external_baselines': external_df.to_dict(orient='records') if not external_df.empty else [],
    'assembly': assembly_df.to_dict(orient='records') if not assembly_df.empty else [],
    'variant_calling': variant_df.to_dict(orient='records') if not variant_df.empty else [],
}
summary_path = OUT_ROOT / 'benchmark_summary.json'
summary_path.write_text(json.dumps(combined_summary, indent=2))
print('benchmark summary saved to', summary_path)
# Out:
# No correction summaries found yet.
# No external baseline summaries found yet.
# No assembly summaries found yet.
# No variant-calling summaries found yet.
# benchmark summary saved to /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/benchmark_summary.json

# %%
print('\n=== preprocess plan ===')
for row in preprocess_plans:
    print(f'\n[{row["stage"]}] [{row["dataset"]}]')
    print(stringify_cmd(row['cmd']))

print('\n=== training plan ===')
for row in train_plans:
    print(f'\n[{row["stage"]}] [{row["run"]}]')
    print('train:', stringify_cmd(row['cmd']))

print('\n=== evaluation plan ===')
for row in eval_plans:
    print(f'\n[{row["dataset"]}] [{row["run"]}]')
    print('test:', stringify_cmd(row['cmd']))

print('\n=== internal baselines ===')
for row in baseline_plans:
    print(f'{row["dataset"]} / {row["baseline"]}:', stringify_cmd(row['cmd']))

print('\n=== external baseline hooks ===')
for row in external_baseline_plans:
    print(f'{row["dataset"]} / {row["tool"]}:', stringify_cmd(row['cmd']))

print('\n=== downstream hooks ===')
for row in downstream_plans:
    print(f'{row["dataset"]} / {row["kind"]}:', stringify_cmd(row['cmd']))
# Out:
# === preprocess plan ===
#
# [chr20_small] [hg002_chr20_primary_8x]
# /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/preprocess_real_data.py --reads-bam /Users/shanejayasundera/LRS-Error-Correction/data/subsets/hg002_chr20_8x/HG002.giab.subset.bam --reference-fasta /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna --output-dir /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_8x/chr20_small --window-size 2048 --window-overlap 512 --min-window-size 1024 --max-supports 24 --min-supports-per-window 4 --min-mapq 20 --min-read-length 10000 --max-deletion-length 4 --train-contigs chr20 --val-contigs chr20 --test-contigs chr20 --allow-shared-holdout-contigs --max-examples-per-split 1500 --truth-vcf /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark.vcf.gz --confident-bed /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark_noinconsistent.bed --haplotagged-bam /Users/shanejayasundera/LRS-Error-Correction/data/subsets/hg002_chr20_8x/HG002.giab.subset.bam
#
# [chr20_small] [hg002_chr20_primary_12x]
# /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/preprocess_real_data.py --reads-bam /Users/shanejayasundera/LRS-Error-Correction/data/subsets/hg002_chr20_12x/HG002.giab.subset.bam --reference-fasta /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna --output-dir /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_12x/chr20_small --window-size 2048 --window-overlap 512 --min-window-size 1024 --max-supports 24 --min-supports-per-window 4 --min-mapq 20 --min-read-length 10000 --max-deletion-length 4 --train-contigs chr20 --val-contigs chr20 --test-contigs chr20 --allow-shared-holdout-contigs --max-examples-per-split 1500 --truth-vcf /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark.vcf.gz --confident-bed /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark_noinconsistent.bed --haplotagged-bam /Users/shanejayasundera/LRS-Error-Correction/data/subsets/hg002_chr20_12x/HG002.giab.subset.bam
#
# [chr20_small] [hg002_chr20_primary_20x]
# /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/preprocess_real_data.py --reads-bam /Users/shanejayasundera/LRS-Error-Correction/data/subsets/hg002_chr20_20x/HG002.giab.subset.bam --reference-fasta /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna --output-dir /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_20x/chr20_small --window-size 2048 --window-overlap 512 --min-window-size 1024 --max-supports 24 --min-supports-per-window 4 --min-mapq 20 --min-read-length 10000 --max-deletion-length 4 --train-contigs chr20 --val-contigs chr20 --test-contigs chr20 --allow-shared-holdout-contigs --max-examples-per-split 1500 --truth-vcf /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark.vcf.gz --confident-bed /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark_noinconsistent.bed --haplotagged-bam /Users/shanejayasundera/LRS-Error-Correction/data/subsets/hg002_chr20_20x/HG002.giab.subset.bam
#
# === training plan ===
#
# [chr20_small] [full]
# train: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/train.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/8x_chr20_small_full.yaml
#
# [chr20_small] [full]
# train: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/train.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/12x_chr20_small_full.yaml
#
# [chr20_small] [full]
# train: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/train.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/20x_chr20_small_full.yaml
#
# === evaluation plan ===
#
# [hg002_chr20_primary_8x] [full]
# test: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/test.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/8x_chr20_small_full.yaml --checkpoint /Users/shanejayasundera/LRS-Error-Correction/checkpoints/hg002_chr20_small_benchmark/8x/chr20_small/full/best_model.pt --data-path /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_8x/chr20_small/test.jsonl --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/full/test_summary.json --predictions-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/full/test_predictions.jsonl
#
# [hg002_chr20_primary_12x] [full]
# test: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/test.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/12x_chr20_small_full.yaml --checkpoint /Users/shanejayasundera/LRS-Error-Correction/checkpoints/hg002_chr20_small_benchmark/12x/chr20_small/full/best_model.pt --data-path /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_12x/chr20_small/test.jsonl --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/12x/chr20_small/hg002_chr20_primary_12x/full/test_summary.json --predictions-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/12x/chr20_small/hg002_chr20_primary_12x/full/test_predictions.jsonl
#
# [hg002_chr20_primary_20x] [full]
# test: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/test.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/20x_chr20_small_full.yaml --checkpoint /Users/shanejayasundera/LRS-Error-Correction/checkpoints/hg002_chr20_small_benchmark/20x/chr20_small/full/best_model.pt --data-path /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_20x/chr20_small/test.jsonl --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/20x/chr20_small/hg002_chr20_primary_20x/full/test_summary.json --predictions-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/20x/chr20_small/hg002_chr20_primary_20x/full/test_predictions.jsonl
#
# === internal baselines ===
# hg002_chr20_primary_8x / no_edit: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/no_edit_baseline.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/8x_chr20_small_full.yaml --data-path /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_8x/chr20_small/test.jsonl --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/baselines/no_edit_summary.json --predictions-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/baselines/no_edit_predictions.jsonl
# hg002_chr20_primary_8x / consensus: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/consensus_baseline.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/8x_chr20_small_full.yaml --data-path /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_8x/chr20_small/test.jsonl --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/baselines/consensus_summary.json --predictions-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/baselines/consensus_predictions.jsonl
# hg002_chr20_primary_12x / no_edit: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/no_edit_baseline.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/12x_chr20_small_full.yaml --data-path /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_12x/chr20_small/test.jsonl --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/12x/chr20_small/hg002_chr20_primary_12x/baselines/no_edit_summary.json --predictions-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/12x/chr20_small/hg002_chr20_primary_12x/baselines/no_edit_predictions.jsonl
# hg002_chr20_primary_12x / consensus: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/consensus_baseline.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/12x_chr20_small_full.yaml --data-path /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_12x/chr20_small/test.jsonl --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/12x/chr20_small/hg002_chr20_primary_12x/baselines/consensus_summary.json --predictions-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/12x/chr20_small/hg002_chr20_primary_12x/baselines/consensus_predictions.jsonl
# hg002_chr20_primary_20x / no_edit: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/no_edit_baseline.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/20x_chr20_small_full.yaml --data-path /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_20x/chr20_small/test.jsonl --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/20x/chr20_small/hg002_chr20_primary_20x/baselines/no_edit_summary.json --predictions-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/20x/chr20_small/hg002_chr20_primary_20x/baselines/no_edit_predictions.jsonl
# hg002_chr20_primary_20x / consensus: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/consensus_baseline.py --config /Users/shanejayasundera/LRS-Error-Correction/configs/hg002_chr20_small_benchmark/20x_chr20_small_full.yaml --data-path /Users/shanejayasundera/LRS-Error-Correction/data/hg002_chr20_small_benchmark/hg002_chr20_primary_20x/chr20_small/test.jsonl --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/20x/chr20_small/hg002_chr20_primary_20x/baselines/consensus_summary.json --predictions-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/20x/chr20_small/hg002_chr20_primary_20x/baselines/consensus_predictions.jsonl
#
# === external baseline hooks ===
# hg002_chr20_primary_8x / herro: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/run_external_baseline.py --tool herro --reads-bam /Users/shanejayasundera/LRS-Error-Correction/data/subsets/hg002_chr20_8x/HG002.giab.subset.bam --reference-fasta /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna --output-dir /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/external_baselines/herro --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/external_baselines/herro_summary.json
# hg002_chr20_primary_8x / dechat: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/run_external_baseline.py --tool dechat --reads-bam /Users/shanejayasundera/LRS-Error-Correction/data/subsets/hg002_chr20_8x/HG002.giab.subset.bam --reference-fasta /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna --output-dir /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/external_baselines/dechat --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/external_baselines/dechat_summary.json
#
# === downstream hooks ===
# hg002_chr20_primary_8x / export: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/export_predictions_to_fastx.py --predictions-jsonl /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/full/test_predictions.jsonl --output /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/downstream/corrected_reads.fasta --format fasta
# hg002_chr20_primary_8x / assembly: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/run_assembly_eval.py --reads-fastx /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/downstream/corrected_reads.fasta --reference-fasta /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna --output-dir /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/downstream/assembly --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/downstream/assembly_summary.json
# hg002_chr20_primary_8x / variant_eval: /Users/shanejayasundera/anaconda3/envs/lrs_err_correct_env/bin/python scripts/run_variant_eval.py --reads-fastx /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/downstream/corrected_reads.fasta --reference-fasta /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna --truth-vcf /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark.vcf.gz --confident-bed /Users/shanejayasundera/LRS-Error-Correction/data/raw/giab/hg002/HG002_GRCh38_1_22_v4.2.1_benchmark_noinconsistent.bed --output-dir /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/downstream/variant_eval --summary-out /Users/shanejayasundera/LRS-Error-Correction/outputs/hg002_chr20_small_benchmark/8x/chr20_small/hg002_chr20_primary_8x/downstream/variant_eval_summary.json
